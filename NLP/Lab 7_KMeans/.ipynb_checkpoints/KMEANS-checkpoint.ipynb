# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %%
with open('data.txt', 'r') as f:
    lines = f.readlines()

# %%
def pre_process(data):
    clean_data = []
    for sentence in data:
        sentence = sentence.lower()
        sentence = sentence.replace('\n',"")
        sentence = re.sub(r'[^\w\s.]', '', sentence)
        sentence = re.sub(r'\b(\w+)\.', r'\1', sentence)
        clean_data.append(sentence)
    return clean_data
#         print(sentence)

# %%
pre_processed_data = pre_process(lines)
# pre_processed_data

# %%
vectorizer = TfidfVectorizer()

# %%
vectorizer
# Out:
# TfidfVectorizer()

# %%
tfidf_matrix = vectorizer.fit_transform(pre_processed_data)

# %%
tfidf_matrix
# Out:
# <30x210 sparse matrix of type '<class 'numpy.float64'>'
# 	with 290 stored elements in Compressed Sparse Row format>

# %%
kmeans = KMeans(n_clusters=2, random_state=0)

# %%
kmeans.fit(tfidf_matrix)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
# for i, sentence in enumerate(pre_processed_data):
#     print(f"Sentence: {sentence}")
#     print(f"Cluster: {kmeans.labels_[i]}")
#     print("-" * 20)

# %% [markdown]
# ## All sentences in Cluster 0

# %%
for i, sentence in enumerate(pre_processed_data):
    if kmeans.labels_[i] == 0:
        print(f"Sentence: {sentence}")
        print(f"Cluster: {kmeans.labels_[i]}")
# Out:
# Sentence: our team excels at developing cuttingedge webbased applications
# Cluster: 0
# Sentence: we consistently monitor our network infrastructure for potential vulnerabilities
# Cluster: 0
# Sentence: upgrading our database system significantly enhanced query performance
# Cluster: 0
# Sentence: our data scientists are experts in extracting actionable trends
# Cluster: 0
# Sentence: our company is committed to implementing sustainable practices across all operations
# Cluster: 0
# Sentence: reducing our carbon footprint is a top priority for our organization
# Cluster: 0
# Sentence: we utilize renewable energy sources to power our facilities
# Cluster: 0
# Sentence: our company aims to achieve zero waste through a comprehensive recycling program
# Cluster: 0
# Sentence: reducing water consumption is an important part of our environmental policy
# Cluster: 0
# Sentence: environmental awareness campaigns aim to educate and inspire action
# Cluster: 0
# Sentence: partnering with environmental organizations amplifies our sustainability impact
# Cluster: 0
# Sentence: we strive to minimize our impact on delicate ecosystems
# Cluster: 0
# Sentence: its essential to support environmental legislation that protects our natural resources
# Cluster: 0

# %% [markdown]
# ## All sentences in Cluster 2

# %%
# print('total sentences in cluster 2:')



for i, sentence in enumerate(pre_processed_data):
    if kmeans.labels_[i] == 1:
        print(f"Sentence: {sentence}")
        print(f"Cluster: {kmeans.labels_[i]}")
# Out:
# Sentence: the software update rolled out smoothly enhancing user experience significantly
# Cluster: 1
# Sentence: disruptive technologies are revolutionizing the way businesses operate
# Cluster: 1
# Sentence: cloud computing services offer flexibility and scalability for data storage
# Cluster: 1
# Sentence: user interface design is key to delivering a seamless software experience
# Cluster: 1
# Sentence: big data analytics are providing insights that drive better business decisions
# Cluster: 1
# Sentence: we need to prioritize cybersecurity measures to safeguard sensitive data
# Cluster: 1
# Sentence: the new aipowered algorithm is remarkably efficient in processing complex data sets
# Cluster: 1
# Sentence: have you considered adopting a devsecops framework for secure software development
# Cluster: 1
# Sentence: continuous integration and deployment streamline our software release cycles
# Cluster: 1
# Sentence: machine learning models help us automate key prediction tasks
# Cluster: 1
# Sentence: investing in research and development is crucial to staying ahead of the technology curve
# Cluster: 1
# Sentence: protecting biodiversity is crucial for a healthy planet
# Cluster: 1
# Sentence: sustainable agriculture techniques help nourish communities and protect the environment
# Cluster: 1
# Sentence: composting programs help reduce landfill waste and create nutrientrich soil
# Cluster: 1
# Sentence: investing in clean energy solutions is vital for combating climate change
# Cluster: 1
# Sentence: promoting ecofriendly transportation options can reduce air pollution
# Cluster: 1
# Sentence: each individual can make choices that contribute to a greener future
# Cluster: 1

# %%
kmeans.labels_[1]
# Out:
# 1

# %%
def display_condensed_tfidf(tfidf_matrix, vectorizer):
    """Displays a condensed view of the TF-IDF matrix."""

    n_docs = tfidf_matrix.shape[0]
    for i in range(n_docs):
        doc_terms = {}  
        row = tfidf_matrix.getrow(i)

        for term_index, score in zip(row.indices, row.data):
            term = vectorizer.get_feature_names_out()[term_index]
            doc_terms[term] = score

        print(f"Document {i}:")
        for term, score in doc_terms.items():
            print(f"  * {term}: {score:.3f}")
        print()

display_condensed_tfidf(tfidf_matrix, vectorizer)
# Out:
# Document 0:
#   * significantly: 0.307
#   * experience: 0.307
#   * user: 0.307
#   * enhancing: 0.344
#   * smoothly: 0.344
#   * out: 0.344
#   * rolled: 0.344
#   * update: 0.344
#   * software: 0.260
#   * the: 0.243
#
# Document 1:
#   * operate: 0.374
#   * businesses: 0.374
#   * way: 0.374
#   * revolutionizing: 0.374
#   * are: 0.304
#   * technologies: 0.374
#   * disruptive: 0.374
#   * the: 0.264
#
# Document 2:
#   * storage: 0.345
#   * data: 0.244
#   * for: 0.230
#   * scalability: 0.345
#   * and: 0.230
#   * flexibility: 0.345
#   * offer: 0.345
#   * services: 0.345
#   * computing: 0.345
#   * cloud: 0.345
#
# Document 3:
#   * seamless: 0.363
#   * delivering: 0.363
#   * to: 0.197
#   * key: 0.323
#   * is: 0.217
#   * design: 0.363
#   * interface: 0.363
#   * experience: 0.323
#   * user: 0.323
#   * software: 0.274
#
# Document 4:
#   * decisions: 0.319
#   * business: 0.319
#   * better: 0.319
#   * drive: 0.319
#   * that: 0.260
#   * insights: 0.319
#   * providing: 0.319
#   * analytics: 0.319
#   * big: 0.319
#   * data: 0.225
#   * are: 0.260
#
# Document 5:
#   * applications: 0.372
#   * webbased: 0.372
#   * cuttingedge: 0.372
#   * developing: 0.372
#   * at: 0.372
#   * excels: 0.372
#   * team: 0.372
#   * our: 0.178
#
# Document 6:
#   * sensitive: 0.348
#   * safeguard: 0.348
#   * measures: 0.348
#   * cybersecurity: 0.348
#   * prioritize: 0.348
#   * need: 0.348
#   * we: 0.263
#   * to: 0.379
#   * data: 0.246
#
# Document 7:
#   * sets: 0.317
#   * complex: 0.317
#   * processing: 0.317
#   * in: 0.240
#   * efficient: 0.317
#   * remarkably: 0.317
#   * algorithm: 0.317
#   * aipowered: 0.317
#   * new: 0.317
#   * is: 0.190
#   * data: 0.224
#   * the: 0.224
#
# Document 8:
#   * development: 0.300
#   * secure: 0.337
#   * framework: 0.337
#   * devsecops: 0.337
#   * adopting: 0.337
#   * considered: 0.337
#   * you: 0.337
#   * have: 0.337
#   * for: 0.224
#   * software: 0.254
#
# Document 9:
#   * vulnerabilities: 0.372
#   * potential: 0.372
#   * infrastructure: 0.372
#   * network: 0.372
#   * monitor: 0.372
#   * consistently: 0.372
#   * we: 0.281
#   * our: 0.178
#   * for: 0.247
#
# Document 10:
#   * cycles: 0.372
#   * release: 0.372
#   * streamline: 0.372
#   * deployment: 0.372
#   * integration: 0.372
#   * continuous: 0.372
#   * our: 0.178
#   * and: 0.247
#   * software: 0.281
#
# Document 11:
#   * performance: 0.377
#   * query: 0.377
#   * enhanced: 0.377
#   * system: 0.377
#   * database: 0.377
#   * upgrading: 0.377
#   * our: 0.181
#   * significantly: 0.336
#
# Document 12:
#   * trends: 0.379
#   * actionable: 0.379
#   * extracting: 0.379
#   * experts: 0.379
#   * scientists: 0.379
#   * in: 0.286
#   * our: 0.182
#   * data: 0.268
#   * are: 0.309
#
# Document 13:
#   * tasks: 0.344
#   * prediction: 0.344
#   * automate: 0.344
#   * us: 0.344
#   * help: 0.280
#   * models: 0.344
#   * learning: 0.344
#   * machine: 0.344
#   * key: 0.307
#
# Document 14:
#   * curve: 0.311
#   * technology: 0.311
#   * of: 0.277
#   * ahead: 0.311
#   * staying: 0.311
#   * crucial: 0.277
#   * research: 0.311
#   * investing: 0.277
#   * development: 0.277
#   * in: 0.235
#   * to: 0.169
#   * is: 0.186
#   * and: 0.207
#   * the: 0.220
#
# Document 15:
#   * operations: 0.344
#   * all: 0.344
#   * across: 0.344
#   * practices: 0.344
#   * sustainable: 0.306
#   * implementing: 0.344
#   * committed: 0.344
#   * company: 0.306
#   * our: 0.165
#   * to: 0.187
#   * is: 0.205
#
# Document 16:
#   * organization: 0.365
#   * priority: 0.365
#   * top: 0.365
#   * footprint: 0.365
#   * carbon: 0.365
#   * reducing: 0.325
#   * our: 0.350
#   * is: 0.218
#   * for: 0.243
#
# Document 17:
#   * facilities: 0.381
#   * power: 0.381
#   * sources: 0.381
#   * energy: 0.340
#   * renewable: 0.381
#   * utilize: 0.381
#   * we: 0.288
#   * our: 0.183
#   * to: 0.207
#
# Document 18:
#   * program: 0.331
#   * recycling: 0.331
#   * comprehensive: 0.331
#   * through: 0.331
#   * waste: 0.295
#   * zero: 0.331
#   * achieve: 0.331
#   * aims: 0.331
#   * company: 0.295
#   * our: 0.159
#   * to: 0.180
#
# Document 19:
#   * policy: 0.338
#   * environmental: 0.255
#   * part: 0.338
#   * important: 0.338
#   * an: 0.338
#   * consumption: 0.338
#   * water: 0.338
#   * reducing: 0.301
#   * of: 0.301
#   * our: 0.162
#   * is: 0.202
#
# Document 20:
#   * planet: 0.423
#   * healthy: 0.423
#   * biodiversity: 0.423
#   * protecting: 0.423
#   * crucial: 0.377
#   * is: 0.253
#   * for: 0.281
#
# Document 21:
#   * environment: 0.345
#   * protect: 0.345
#   * communities: 0.345
#   * nourish: 0.345
#   * techniques: 0.345
#   * agriculture: 0.345
#   * sustainable: 0.308
#   * help: 0.281
#   * and: 0.229
#   * the: 0.244
#
# Document 22:
#   * action: 0.370
#   * inspire: 0.370
#   * educate: 0.370
#   * aim: 0.370
#   * campaigns: 0.370
#   * awareness: 0.370
#   * environmental: 0.279
#   * to: 0.201
#   * and: 0.246
#
# Document 23:
#   * soil: 0.339
#   * nutrientrich: 0.339
#   * create: 0.339
#   * landfill: 0.339
#   * reduce: 0.302
#   * programs: 0.339
#   * composting: 0.339
#   * waste: 0.302
#   * help: 0.276
#   * and: 0.226
#
# Document 24:
#   * impact: 0.347
#   * sustainability: 0.389
#   * amplifies: 0.389
#   * organizations: 0.389
#   * with: 0.389
#   * partnering: 0.389
#   * environmental: 0.294
#   * our: 0.187
#
# Document 25:
#   * change: 0.334
#   * climate: 0.334
#   * combating: 0.334
#   * vital: 0.334
#   * solutions: 0.334
#   * clean: 0.334
#   * energy: 0.298
#   * investing: 0.298
#   * in: 0.252
#   * is: 0.200
#   * for: 0.222
#
# Document 26:
#   * ecosystems: 0.381
#   * delicate: 0.381
#   * on: 0.381
#   * minimize: 0.381
#   * strive: 0.381
#   * impact: 0.340
#   * we: 0.288
#   * our: 0.183
#   * to: 0.207
#
# Document 27:
#   * resources: 0.338
#   * natural: 0.338
#   * protects: 0.338
#   * legislation: 0.338
#   * support: 0.338
#   * essential: 0.338
#   * its: 0.338
#   * environmental: 0.255
#   * our: 0.162
#   * that: 0.275
#   * to: 0.184
#
# Document 28:
#   * pollution: 0.363
#   * air: 0.363
#   * can: 0.324
#   * options: 0.363
#   * transportation: 0.363
#   * ecofriendly: 0.363
#   * promoting: 0.363
#   * reduce: 0.324
#
# Document 29:
#   * future: 0.338
#   * greener: 0.338
#   * contribute: 0.338
#   * choices: 0.338
#   * make: 0.338
#   * individual: 0.338
#   * each: 0.338
#   * can: 0.301
#   * that: 0.275
#   * to: 0.184

# %%
def display_full_tfidf(tfidf_matrix, vectorizer):
    n_docs, n_terms = tfidf_matrix.shape
    feature_names = vectorizer.get_feature_names_out()

    for doc_index in range(n_docs):
        print(f"Document {doc_index}:")
        for word_index in range(n_terms):
            word = feature_names[word_index]
            score = tfidf_matrix[doc_index, word_index]
            print(f"  * {word}: {score:.3f}")
        print()

display_full_tfidf(tfidf_matrix, vectorizer)
# Out:
# Document 0:
#   * achieve: 0.000
#   * across: 0.000
#   * action: 0.000
#   * actionable: 0.000
#   * adopting: 0.000
#   * agriculture: 0.000
#   * ahead: 0.000
#   * aim: 0.000
#   * aims: 0.000
#   * aipowered: 0.000
#   * air: 0.000
#   * algorithm: 0.000
#   * all: 0.000
#   * amplifies: 0.000
#   * an: 0.000
#   * analytics: 0.000
#   * and: 0.000
#   * applications: 0.000
#   * are: 0.000
#   * at: 0.000
#   * automate: 0.000
#   * awareness: 0.000
#   * better: 0.000
#   * big: 0.000
#   * biodiversity: 0.000
#   * business: 0.000
#   * businesses: 0.000
#   * campaigns: 0.000
#   * can: 0.000
#   * carbon: 0.000
#   * change: 0.000
#   * choices: 0.000
#   * clean: 0.000
#   * climate: 0.000
#   * cloud: 0.000
#   * combating: 0.000
#   * committed: 0.000
#   * communities: 0.000
#   * company: 0.000
#   * complex: 0.000
#   * composting: 0.000
#   * comprehensive: 0.000
#   * computing: 0.000
#   * considered: 0.000
#   * consistently: 0.000
#   * consumption: 0.000
#   * continuous: 0.000
#   * contribute: 0.000
#   * create: 0.000
#   * crucial: 0.000
#   * curve: 0.000
#   * cuttingedge: 0.000
#   * cybersecurity: 0.000
#   * cycles: 0.000
#   * data: 0.000
#   * database: 0.000
#   * decisions: 0.000
#   * delicate: 0.000
#   * delivering: 0.000
#   * deployment: 0.000
#   * design: 0.000
#   * developing: 0.000
#   * development: 0.000
#   * devsecops: 0.000
#   * disruptive: 0.000
#   * drive: 0.000
#   * each: 0.000
#   * ecofriendly: 0.000
#   * ecosystems: 0.000
#   * educate: 0.000
#   * efficient: 0.000
#   * energy: 0.000
#   * enhanced: 0.000
#   * enhancing: 0.344
#   * environment: 0.000
#   * environmental: 0.000
#   * essential: 0.000
#   * excels: 0.000
#   * experience: 0.307
#   * experts: 0.000
#   * extracting: 0.000
#   * facilities: 0.000
#   * flexibility: 0.000
#   * footprint: 0.000
#   * for: 0.000
#   * framework: 0.000
#   * future: 0.000
#   * greener: 0.000
#   * have: 0.000
#   * healthy: 0.000
#   * help: 0.000
#   * impact: 0.000
#   * implementing: 0.000
#   * important: 0.000
#   * in: 0.000
#   * individual: 0.000
#   * infrastructure: 0.000
#   * insights: 0.000
#   * inspire: 0.000
#   * integration: 0.000
#   * interface: 0.000
#   * investing: 0.000
#   * is: 0.000
#   * its: 0.000
#   * key: 0.000
#   * landfill: 0.000
#   * learning: 0.000
#   * legislation: 0.000
#   * machine: 0.000
#   * make: 0.000
#   * measures: 0.000
#   * minimize: 0.000
#   * models: 0.000
#   * monitor: 0.000
#   * natural: 0.000
#   * need: 0.000
#   * network: 0.000
#   * new: 0.000
#   * nourish: 0.000
#   * nutrientrich: 0.000
#   * of: 0.000
#   * offer: 0.000
#   * on: 0.000
#   * operate: 0.000
#   * operations: 0.000
#   * options: 0.000
#   * organization: 0.000
#   * organizations: 0.000
#   * our: 0.000
#   * out: 0.344
#   * part: 0.000
#   * partnering: 0.000
#   * performance: 0.000
#   * planet: 0.000
#   * policy: 0.000
#   * pollution: 0.000
#   * potential: 0.000
#   * power: 0.000
#   * practices: 0.000
#   * prediction: 0.000
#   * prioritize: 0.000
#   * priority: 0.000
#   * processing: 0.000
#   * program: 0.000
#   * programs: 0.000
#   * promoting: 0.000
#   * protect: 0.000
#   * protecting: 0.000
#   * protects: 0.000
#   * providing: 0.000
#   * query: 0.000
#   * recycling: 0.000
#   * reduce: 0.000
#   * reducing: 0.000
#   * release: 0.000
#   * remarkably: 0.000
#   * renewable: 0.000
#   * research: 0.000
#   * resources: 0.000
#   * revolutionizing: 0.000
#   * rolled: 0.344
#   * safeguard: 0.000
#   * scalability: 0.000
#   * scientists: 0.000
#   * seamless: 0.000
#   * secure: 0.000
#   * sensitive: 0.000
#   * services: 0.000
#   * sets: 0.000
#   * significantly: 0.307
#   * smoothly: 0.344
#   * software: 0.260
#   * soil: 0.000
#   * solutions: 0.000
#   * sources: 0.000
#   * staying: 0.000
#   * storage: 0.000
#   * streamline: 0.000
#   * strive: 0.000
#   * support: 0.000
#   * sustainability: 0.000
#   * sustainable: 0.000
#   * system: 0.000
#   * tasks: 0.000
#   * team: 0.000
#   * techniques: 0.000
#   * technologies: 0.000
#   * technology: 0.000
#   * that: 0.000
#   * the: 0.243
#   * through: 0.000
#   * to: 0.000
#   * top: 0.000
#   * transportation: 0.000
#   * trends: 0.000
#   * update: 0.344
#   * upgrading: 0.000
#   * us: 0.000
#   * user: 0.307
#   * utilize: 0.000
#   * vital: 0.000
#   * vulnerabilities: 0.000
#   * waste: 0.000
#   * water: 0.000
#   * way: 0.000
#   * we: 0.000
#   * webbased: 0.000
#   * with: 0.000
#   * you: 0.000
#   * zero: 0.000
#
# Document 1:
#   * achieve: 0.000
#   * across: 0.000
#   * action: 0.000
#   * actionable: 0.000
#   * adopting: 0.000
#   * agriculture: 0.000
#   * ahead: 0.000
#   * aim: 0.000
#   * aims: 0.000
#   * aipowered: 0.000
#   * air: 0.000
#   * algorithm: 0.000
#   * all: 0.000
#   * amplifies: 0.000
#   * an: 0.000
#   * analytics: 0.000
#   * and: 0.000
#   * applications: 0.000
#   * are: 0.304
#   * at: 0.000
#   * automate: 0.000
#   * awareness: 0.000
#   * better: 0.000
#   * big: 0.000
#   * biodiversity: 0.000
#   * business: 0.000
#   * businesses: 0.374
#   * campaigns: 0.000
#   * can: 0.000
#   * carbon: 0.000
#   * change: 0.000
#   * choices: 0.000
#   * clean: 0.000
#   * climate: 0.000
#   * cloud: 0.000
#   * combating: 0.000
#   * committed: 0.000
#   * communities: 0.000
#   * company: 0.000
#   * complex: 0.000
#   * composting: 0.000
#   * comprehensive: 0.000
#   * computing: 0.000
#   * considered: 0.000
#   * consistently: 0.000
#   * consumption: 0.000
#   * continuous: 0.000
#   * contribute: 0.000
#   * create: 0.000
#   * crucial: 0.000
#   * curve: 0.000
#   * cuttingedge: 0.000
#   * cybersecurity: 0.000
#   * cycles: 0.000
#   * data: 0.000
#   * database: 0.000
#   * decisions: 0.000
#   * delicate: 0.000
#   * delivering: 0.000
#   * deployment: 0.000
#   * design: 0.000
#   * developing: 0.000
#   * development: 0.000
#   * devsecops: 0.000
#   * disruptive: 0.374
#   * drive: 0.000
#   * each: 0.000
#   * ecofriendly: 0.000
#   * ecosystems: 0.000
#   * educate: 0.000
#   * efficient: 0.000
#   * energy: 0.000
#   * enhanced: 0.000
#   * enhancing: 0.000
#   * environment: 0.000
#   * environmental: 0.000
#   * essential: 0.000
#   * excels: 0.000
#   * experience: 0.000
#   * experts: 0.000
#   * extracting: 0.000
#   * facilities: 0.000
#   * flexibility: 0.000
#   * footprint: 0.000
#   * for: 0.000
#   * framework: 0.000
#   * future: 0.000
#   * greener: 0.000
#   * have: 0.000
#   * healthy: 0.000
#   * help: 0.000
#   * impact: 0.000
#   * implementing: 0.000
#   * important: 0.000
#   * in: 0.000
#   * individual: 0.000
#   * infrastructure: 0.000
#   * insights: 0.000
#   * inspire: 0.000
#   * integration: 0.000
#   * interface: 0.000
#   * investing: 0.000
#   * is: 0.000
#   * its: 0.000
#   * key: 0.000
#   * landfill: 0.000
#   * learning: 0.000
#   * legislation: 0.000
#   * machine: 0.000
#   * make: 0.000
#   * measures: 0.000
#   * minimize: 0.000
#   * models: 0.000
#   * monitor: 0.000
#   * natural: 0.000
#   * need: 0.000
#   * network: 0.000
#   * new: 0.000
#   * nourish: 0.000
#   * nutrientrich: 0.000
#   * of: 0.000
#   * offer: 0.000
#   * on: 0.000
#   * operate: 0.374
#   * operations: 0.000
#   * options: 0.000
#   * organization: 0.000
#   * organizations: 0.000
#   * our: 0.000
#   * out: 0.000
#   * part: 0.000
#   * partnering: 0.000
#   * performance: 0.000
#   * planet: 0.000
#   * policy: 0.000
#   * pollution: 0.000
#   * potential: 0.000
#   * power: 0.000
#   * practices: 0.000
#   * prediction: 0.000
#   * prioritize: 0.000
#   * priority: 0.000
#   * processing: 0.000
#   * program: 0.000
#   * programs: 0.000
#   * promoting: 0.000
#   * protect: 0.000
#   * protecting: 0.000
#   * protects: 0.000
#   * providing: 0.000
#   * query: 0.000
#   * recycling: 0.000
#   * reduce: 0.000
#   * reducing: 0.000
#   * release: 0.000
#   * remarkably: 0.000
#   * renewable: 0.000
#   * research: 0.000
#   * resources: 0.000
#   * revolutionizing: 0.374
#   * rolled: 0.000
#   * safeguard: 0.000
#   * scalability: 0.000
#   * scientists: 0.000
#   * seamless: 0.000
#   * secure: 0.000
#   * sensitive: 0.000
#   * services: 0.000
#   * sets: 0.000
#   * significantly: 0.000
#   * smoothly: 0.000
#   * software: 0.000
#   * soil: 0.000
#   * solutions: 0.000
#   * sources: 0.000
#   * staying: 0.000
#   * storage: 0.000
#   * streamline: 0.000
#   * strive: 0.000
#   * support: 0.000
#   * sustainability: 0.000
#   * sustainable: 0.000
#   * system: 0.000
#   * tasks: 0.000
#   * team: 0.000
#   * techniques: 0.000
#   * technologies: 0.374
#   * technology: 0.000
#   * that: 0.000
#   * the: 0.264
#   * through: 0.000
#   * to: 0.000
#   * top: 0.000
#   * transportation: 0.000
#   * trends: 0.000
#   * update: 0.000
#   * upgrading: 0.000
#   * us: 0.000
#   * user: 0.000
#   * utilize: 0.000
#   * vital: 0.000
#   * vulnerabilities: 0.000
#   * waste: 0.000
#   * water: 0.000
#   * way: 0.374
#   * we: 0.000
#   * webbased: 0.000
#   * with: 0.000
#   * you: 0.000
#   * zero: 0.000
#
# Document 2:
#   * achieve: 0.000
#   * across: 0.000
#   * action: 0.000
#   * actionable: 0.000
#   * adopting: 0.000
#   * agriculture: 0.000
#   * ahead: 0.000
#   * aim: 0.000
#   * aims: 0.000
#   * aipowered: 0.000
#   * air: 0.000
#   * algorithm: 0.000
#   * all: 0.000
#   * amplifies: 0.000
#   * an: 0.000
#   * analytics: 0.000
#   * and: 0.230
#   * applications: 0.000
#   * are: 0.000
#   * at: 0.000
#   * automate: 0.000
#   * awareness: 0.000
#   * better: 0.000
#   * big: 0.000
#   * biodiversity: 0.000
#   * business: 0.000
#   * businesses: 0.000
#   * campaigns: 0.000
#   * can: 0.000
#   * carbon: 0.000
#   * change: 0.000
#   * choices: 0.000
#   * clean: 0.000
#   * climate: 0.000
#   * cloud: 0.345
#   * combating: 0.000
#   * committed: 0.000
#   * communities: 0.000
#   * company: 0.000
#   * complex: 0.000
#   * composting: 0.000
#   * comprehensive: 0.000
#   * computing: 0.345
#   * considered: 0.000
#   * consistently: 0.000
#   * consumption: 0.000
#   * continuous: 0.000
#   * contribute: 0.000
#   * create: 0.000
#   * crucial: 0.000
#   * curve: 0.000
#   * cuttingedge: 0.000
#   * cybersecurity: 0.000
#   * cycles: 0.000
#   * data: 0.244
#   * database: 0.000
#   * decisions: 0.000
#   * delicate: 0.000
#   * delivering: 0.000
#   * deployment: 0.000
#   * design: 0.000
#   * developing: 0.000
#   * development: 0.000
#   * devsecops: 0.000
#   * disruptive: 0.000
#   * drive: 0.000
#   * each: 0.000
#   * ecofriendly: 0.000
#   * ecosystems: 0.000
#   * educate: 0.000
#   * efficient: 0.000
#   * energy: 0.000
#   * enhanced: 0.000
#   * enhancing: 0.000
#   * environment: 0.000
#   * environmental: 0.000
#   * essential: 0.000
#   * excels: 0.000
#   * experience: 0.000
#   * experts: 0.000
#   * extracting: 0.000
#   * facilities: 0.000
#   * flexibility: 0.345
#   * footprint: 0.000
#   * for: 0.230
#   * framework: 0.000
#   * future: 0.000
#   * greener: 0.000
#   * have: 0.000
#   * healthy: 0.000
#   * help: 0.000
#   * impact: 0.000
#   * implementing: 0.000
#   * important: 0.000
#   * in: 0.000
#   * individual: 0.000
#   * infrastructure: 0.000
#   * insights: 0.000
#   * inspire: 0.000
#   * integration: 0.000
#   * interface: 0.000
#   * investing: 0.000
#   * is: 0.000
#   * its: 0.000
#   * key: 0.000
#   * landfill: 0.000
#   * learning: 0.000
#   * legislation: 0.000
#   * machine: 0.000
#   * make: 0.000
#   * measures: 0.000
#   * minimize: 0.000
#   * models: 0.000
#   * monitor: 0.000
#   * natural: 0.000
#   * need: 0.000
#   * network: 0.000
#   * new: 0.000
#   * nourish: 0.000
#   * nutrientrich: 0.000
#   * of: 0.000
#   * offer: 0.345
#   * on: 0.000
#   * operate: 0.000
#   * operations: 0.000
#   * options: 0.000
#   * organization: 0.000
#   * organizations: 0.000
#   * our: 0.000
#   * out: 0.000
#   * part: 0.000
#   * partnering: 0.000
#   * performance: 0.000
#   * planet: 0.000
#   * policy: 0.000
#   * pollution: 0.000
#   * potential: 0.000
#   * power: 0.000
#   * practices: 0.000
#   * prediction: 0.000
#   * prioritize: 0.000
#   * priority: 0.000
#   * processing: 0.000
#   * program: 0.000
#   * programs: 0.000
#   * promoting: 0.000
#   * protect: 0.000
#   * protecting: 0.000
#   * protects: 0.000
#   * providing: 0.000
#   * query: 0.000
#   * recycling: 0.000
#   * reduce: 0.000
#   * reducing: 0.000
#   * release: 0.000
#   * remarkably: 0.000
#   * renewable: 0.000
#   * research: 0.000
#   * resources: 0.000
#   * revolutionizing: 0.000
#   * rolled: 0.000
#   * safeguard: 0.000
#   * scalability: 0.345
#   * scientists: 0.000
#   * seamless: 0.000
#   * secure: 0.000
#   * sensitive: 0.000
#   * services: 0.345
#   * sets: 0.000
#   * significantly: 0.000
#   * smoothly: 0.000
#   * software: 0.000
#   * soil: 0.000
#   * solutions: 0.000
#   * sources: 0.000
#   * staying: 0.000
#   * storage: 0.345
#   * streamline: 0.000
#   * strive: 0.000
#   * support: 0.000
#   * sustainability: 0.000
#   * sustainable: 0.000
#   * system: 0.000
#   * tasks: 0.000
#   * team: 0.000
#   * techniques: 0.000
#   * technologies: 0.000
#   * technology: 0.000
#   * that: 0.000
#   * the: 0.000
#   * through: 0.000
#   * to: 0.000
#   * top: 0.000
#   * transportation: 0.000
#   * trends: 0.000
#   * update: 0.000
#   * upgrading: 0.000
#   * us: 0.000
#   * user: 0.000
#   * utilize: 0.000
#   * vital: 0.000
#   * vulnerabilities: 0.000
#   * waste: 0.000
#   * water: 0.000
#   * way: 0.000
#   * we: 0.000
#   * webbased: 0.000
#   * with: 0.000
#   * you: 0.000
#   * zero: 0.000
#
# Document 3:
#   * achieve: 0.000
#   * across: 0.000
#   * action: 0.000
#   * actionable: 0.000
#   * adopting: 0.000
#   * agriculture: 0.000
#   * ahead: 0.000
#   * aim: 0.000
#   * aims: 0.000
#   * aipowered: 0.000
#   * air: 0.000
#   * algorithm: 0.000
#   * all: 0.000
#   * amplifies: 0.000
#   * an: 0.000
#   * analytics: 0.000
#   * and: 0.000
#   * applications: 0.000
#   * are: 0.000
#   * at: 0.000
#   * automate: 0.000
#   * awareness: 0.000
#   * better: 0.000
#   * big: 0.000
#   * biodiversity: 0.000
#   * business: 0.000
#   * businesses: 0.000
#   * campaigns: 0.000
#   * can: 0.000
#   * carbon: 0.000
#   * change: 0.000
#   * choices: 0.000
#   * clean: 0.000
#   * climate: 0.000
#   * cloud: 0.000
#   * combating: 0.000
#   * committed: 0.000
#   * communities: 0.000
#   * company: 0.000
#   * complex: 0.000
#   * composting: 0.000
#   * comprehensive: 0.000
#   * computing: 0.000
#   * considered: 0.000
#   * consistently: 0.000
#   * consumption: 0.000
#   * continuous: 0.000
#   * contribute: 0.000
#   * create: 0.000
#   * crucial: 0.000
#   * curve: 0.000
#   * cuttingedge: 0.000
#   * cybersecurity: 0.000
#   * cycles: 0.000
#   * data: 0.000
#   * database: 0.000
#   * decisions: 0.000
#   * delicate: 0.000
#   * delivering: 0.363
#   * deployment: 0.000
#   * design: 0.363
#   * developing: 0.000
#   * development: 0.000
#   * devsecops: 0.000
#   * disruptive: 0.000
#   * drive: 0.000
#   * each: 0.000
#   * ecofriendly: 0.000
#   * ecosystems: 0.000
#   * educate: 0.000
#   * efficient: 0.000
#   * energy: 0.000
#   * enhanced: 0.000
#   * enhancing: 0.000
#   * environment: 0.000
#   * environmental: 0.000
#   * essential: 0.000
#   * excels: 0.000
#   * experience: 0.323
#   * experts: 0.000
#   * extracting: 0.000
#   * facilities: 0.000
#   * flexibility: 0.000
#   * footprint: 0.000
#   * for: 0.000
#   * framework: 0.000
#   * future: 0.000
#   * greener: 0.000
#   * have: 0.000
#   * healthy: 0.000
#   * help: 0.000
#   * impact: 0.000
#   * implementing: 0.000
#   * important: 0.000
#   * in: 0.000
#   * individual: 0.000
#   * infrastructure: 0.000
#   * insights: 0.000
#   * inspire: 0.000
#   * integration: 0.000
#   * interface: 0.363
#   * investing: 0.000
#   * is: 0.217
#   * its: 0.000
#   * key: 0.323
#   * landfill: 0.000
#   * learning: 0.000
#   * legislation: 0.000
#   * machine: 0.000
#   * make: 0.000
#   * measures: 0.000
#   * minimize: 0.000
#   * models: 0.000
#   * monitor: 0.000
#   * natural: 0.000
#   * need: 0.000
#   * network: 0.000
#   * new: 0.000
#   * nourish: 0.000
#   * nutrientrich: 0.000
#   * of: 0.000
#   * offer: 0.000
#   * on: 0.000
#   * operate: 0.000
#   * operations: 0.000
#   * options: 0.000
#   * organization: 0.000
#   * organizations: 0.000
#   * our: 0.000
#   * out: 0.000
#   * part: 0.000
#   * partnering: 0.000
#   * performance: 0.000
#   * planet: 0.000
#   * policy: 0.000
#   * pollution: 0.000
#   * potential: 0.000
#   * power: 0.000
#   * practices: 0.000
#   * prediction: 0.000
#   * prioritize: 0.000
#   * priority: 0.000
#   * processing: 0.000
#   * program: 0.000
#   * programs: 0.000
#   * promoting: 0.000
#   * protect: 0.000
#   * protecting: 0.000
#   * protects: 0.000
#   * providing: 0.000
#   * query: 0.000
#   * recycling: 0.000
#   * reduce: 0.000
#   * reducing: 0.000
#   * release: 0.000
#   * remarkably: 0.000
#   * renewable: 0.000
#   * research: 0.000
#   * resources: 0.000
#   * revolutionizing: 0.000
#   * rolled: 0.000
#   * safeguard: 0.000
#   * scalability: 0.000
#   * scientists: 0.000
#   * seamless: 0.363
#   * secure: 0.000
#   * sensitive: 0.000
#   * services: 0.000
#   * sets: 0.000
#   * significantly: 0.000
#   * smoothly: 0.000
#   * software: 0.274
#   * soil: 0.000
#   * solutions: 0.000
#   * sources: 0.000
#   * staying: 0.000
#   * storage: 0.000
#   * streamline: 0.000
#   * strive: 0.000
#   * support: 0.000
#   * sustainability: 0.000
#   * sustainable: 0.000
#   * system: 0.000
#   * tasks: 0.000
#   * team: 0.000
#   * techniques: 0.000
#   * technologies: 0.000
#   * technology: 0.000
#   * that: 0.000
#   * the: 0.000
#   * through: 0.000
#   * to: 0.197
#   * top: 0.000
#   * transportation: 0.000
#   * trends: 0.000
#   * update: 0.000
#   * upgrading: 0.000
#   * us: 0.000
#   * user: 0.323
#   * utilize: 0.000
#   * vital: 0.000
#   * vulnerabilities: 0.000
#   * waste: 0.000
#   * water: 0.000
#   * way: 0.000
#   * we: 0.000
#   * webbased: 0.000
#   * with: 0.000
#   * you: 0.000
#   * zero: 0.000
#
# Document 4:
#   * achieve: 0.000
#   * across: 0.000
#   * action: 0.000
#   * actionable: 0.000
#   * adopting: 0.000
#   * agriculture: 0.000
#   * ahead: 0.000
#   * aim: 0.000
#   * aims: 0.000
#   * aipowered: 0.000
#   * air: 0.000
#   * algorithm: 0.000
#   * all: 0.000
#   * amplifies: 0.000
#   * an: 0.000
#   * analytics: 0.319
#   * and: 0.000
#   * applications: 0.000
#   * are: 0.260
#   * at: 0.000
#   * automate: 0.000
#   * awareness: 0.000
#   * better: 0.319
#   * big: 0.319
#   * biodiversity: 0.000
#   * business: 0.319
#   * businesses: 0.000
#   * campaigns: 0.000
#   * can: 0.000
#   * carbon: 0.000
#   * change: 0.000
#   * choices: 0.000
#   * clean: 0.000
#   * climate: 0.000
#   * cloud: 0.000
#   * combating: 0.000
#   * committed: 0.000
#   * communities: 0.000
#   * company: 0.000
#   * complex: 0.000
#   * composting: 0.000
#   * comprehensive: 0.000
#   * computing: 0.000
#   * considered: 0.000
#   * consistently: 0.000
#   * consumption: 0.000
#   * continuous: 0.000
#   * contribute: 0.000
#   * create: 0.000
#   * crucial: 0.000
#   * curve: 0.000
#   * cuttingedge: 0.000
#   * cybersecurity: 0.000
#   * cycles: 0.000
#   * data: 0.225
#   * database: 0.000
#   * decisions: 0.319
#   * delicate: 0.000
#   * delivering: 0.000
#   * deployment: 0.000
#   * design: 0.000
#   * developing: 0.000
#   * development: 0.000
#   * devsecops: 0.000
#   * disruptive: 0.000
#   * drive: 0.319
#   * each: 0.000
#   * ecofriendly: 0.000
#   * ecosystems: 0.000
#   * educate: 0.000
#   * efficient: 0.000
#   * energy: 0.000
#   * enhanced: 0.000
#   * enhancing: 0.000
#   * environment: 0.000
#   * environmental: 0.000
#   * essential: 0.000
#   * excels: 0.000
#   * experience: 0.000
#   * experts: 0.000
#   * extracting: 0.000
#   * facilities: 0.000
#   * flexibility: 0.000
#   * footprint: 0.000
#   * for: 0.000
#   * framework: 0.000
#   * future: 0.000
#   * greener: 0.000
#   * have: 0.000
#   * healthy: 0.000
#   * help: 0.000
#   * impact: 0.000
#   * implementing: 0.000
#   * important: 0.000
#   * in: 0.000
#   * individual: 0.000
#   * infrastructure: 0.000
#   * insights: 0.319
#   * inspire: 0.000
#   * integration: 0.000
#   * interface: 0.000
#   * investing: 0.000
#   * is: 0.000
#   * its: 0.000
#   * key: 0.000
#   * landfill: 0.000
#   * learning: 0.000
#   * legislation: 0.000
#   * machine: 0.000
#   * make: 0.000
#   * measures: 0.000
#   * minimize: 0.000
#   * models: 0.000
#   * monitor: 0.000
#   * natural: 0.000
#   * need: 0.000
#   * network: 0.000
#   * new: 0.000
#   * nourish: 0.000
#   * nutrientrich: 0.000
#   * of: 0.000
#   * offer: 0.000
#   * on: 0.000
#   * operate: 0.000
#   * operations: 0.000
#   * options: 0.000
#   * organization: 0.000
#   * organizations: 0.000
#   * our: 0.000
#   * out: 0.000
#   * part: 0.000
#   * partnering: 0.000
#   * performance: 0.000
#   * planet: 0.000
#   * policy: 0.000
#   * pollution: 0.000
#   * potential: 0.000
#   * power: 0.000
#   * practices: 0.000
#   * prediction: 0.000
#   * prioritize: 0.000
#   * priority: 0.000
#   * processing: 0.000
#   * program: 0.000
#   * programs: 0.000
#   * promoting: 0.000
#   * protect: 0.000
#   * protecting: 0.000
#   * protects: 0.000
#   * providing: 0.319
#   * query: 0.000
#   * recycling: 0.000
#   * reduce: 0.000
#   * reducing: 0.000
#   * release: 0.000
#   * remarkably: 0.000
#   * renewable: 0.000
#   * research: 0.000
#   * resources: 0.000
#   * revolutionizing: 0.000
#   * rolled: 0.000
#   * safeguard: 0.000
#   * scalability: 0.000
#   * scientists: 0.000
#   * seamless: 0.000
#   * secure: 0.000
#   * sensitive: 0.000
#   * services: 0.000
#   * sets: 0.000
#   * significantly: 0.000
#   * smoothly: 0.000
#   * software: 0.000
#   * soil: 0.000
#   * solutions: 0.000
#   * sources: 0.000
#   * staying: 0.000
#   * storage: 0.000
#   * streamline: 0.000
#   * strive: 0.000
#   * support: 0.000
#   * sustainability: 0.000
#   * sustainable: 0.000
#   * system: 0.000
#   * tasks: 0.000
#   * team: 0.000
#   * techniques: 0.000
#   * technologies: 0.000
#   * technology: 0.000
#   * that: 0.260
#   * the: 0.000
#   * through: 0.000
#   * to: 0.000
#   * top: 0.000
#   * transportation: 0.000
#   * trends: 0.000
#   * update: 0.000
#   * upgrading: 0.000
#   * us: 0.000
#   * user: 0.000
#   * utilize: 0.000
#   * vital: 0.000
#   * vulnerabilities: 0.000
#   * waste: 0.000
#   * water: 0.000
#   * way: 0.000
#   * we: 0.000
#   * webbased: 0.000
#   * with: 0.000
#   * you: 0.000
#   * zero: 0.000
#
# Document 5:
#   * achieve: 0.000
#   * across: 0.000
#   * action: 0.000
#   * actionable: 0.000
#   * adopting: 0.000
#   * agriculture: 0.000
#   * ahead: 0.000
#   * aim: 0.000
#   * aims: 0.000
#   * aipowered: 0.000
#   * air: 0.000
#   * algorithm: 0.000
#   * all: 0.000
#   * amplifies: 0.000
#   * an: 0.000
#   * analytics: 0.000
#   * and: 0.000
#   * applications: 0.372
#   * are: 0.000
#   * at: 0.372
#   * automate: 0.000
#   * awareness: 0.000
#   * better: 0.000
#   * big: 0.000
#   * biodiversity: 0.000
#   * business: 0.000
#   * businesses: 0.000
#   * campaigns: 0.000
#   * can: 0.000
#   * carbon: 0.000
#   * change: 0.000
#   * choices: 0.000
#   * clean: 0.000
#   * climate: 0.000
#   * cloud: 0.000
#   * combating: 0.000
#   * committed: 0.000
#   * communities: 0.000
#   * company: 0.000
#   * complex: 0.000
#   * composting: 0.000
#   * comprehensive: 0.000
#   * computing: 0.000
#   * considered: 0.000
#   * consistently: 0.000
#   * consumption: 0.000
#   * continuous: 0.000
#   * contribute: 0.000
#   * create: 0.000
#   * crucial: 0.000
#   * curve: 0.000
#   * cuttingedge: 0.372
#   * cybersecurity: 0.000
#   * cycles: 0.000
#   * data: 0.000
#   * database: 0.000
#   * decisions: 0.000
#   * delicate: 0.000
#   * delivering: 0.000
#   * deployment: 0.000
#   * design: 0.000
#   * developing: 0.372
#   * development: 0.000
#   * devsecops: 0.000
#   * disruptive: 0.000
#   * drive: 0.000
#   * each: 0.000
#   * ecofriendly: 0.000
#   * ecosystems: 0.000
#   * educate: 0.000
#   * efficient: 0.000
#   * energy: 0.000
#   * enhanced: 0.000
#   * enhancing: 0.000
#   * environment: 0.000
#   * environmental: 0.000
#   * essential: 0.000
#   * excels: 0.372
#   * experience: 0.000
#   * experts: 0.000
#   * extracting: 0.000
#   * facilities: 0.000
#   * flexibility: 0.000
#   * footprint: 0.000
#   * for: 0.000
#   * framework: 0.000
#   * future: 0.000
#   * greener: 0.000
#   * have: 0.000
#   * healthy: 0.000
#   * help: 0.000
#   * impact: 0.000
#   * implementing: 0.000
#   * important: 0.000
#   * in: 0.000
#   * individual: 0.000
#   * infrastructure: 0.000
#   * insights: 0.000
#   * inspire: 0.000
#   * integration: 0.000
#   * interface: 0.000
#   * investing: 0.000
#   * is: 0.000
#   * its: 0.000
#   * key: 0.000
#   * landfill: 0.000
#   * learning: 0.000
#   * legislation: 0.000
#   * machine: 0.000
#   * make: 0.000
#   * measures: 0.000
#   * minimize: 0.000
#   * models: 0.000
#   * monitor: 0.000
#   * natural: 0.000
#   * need: 0.000
#   * network: 0.000
#   * new: 0.000
#   * nourish: 0.000
#   * nutrientrich: 0.000
#   * of: 0.000
#   * offer: 0.000
#   * on: 0.000
#   * operate: 0.000
#   * operations: 0.000
#   * options: 0.000
#   * organization: 0.000
#   * organizations: 0.000
#   * our: 0.178
#   * out: 0.000
#   * part: 0.000
#   * partnering: 0.000
#   * performance: 0.000
#   * planet: 0.000
#   * policy: 0.000
#   * pollution: 0.000
#   * potential: 0.000
#   * power: 0.000
#   * practices: 0.000
#   * prediction: 0.000
#   * prioritize: 0.000
#   * priority: 0.000
#   * processing: 0.000
#   * program: 0.000
#   * programs: 0.000
#   * promoting: 0.000
#   * protect: 0.000
#   * protecting: 0.000
#   * protects: 0.000
#   * providing: 0.000
#   * query: 0.000
#   * recycling: 0.000
#   * reduce: 0.000
#   * reducing: 0.000
#   * release: 0.000
#   * remarkably: 0.000
#   * renewable: 0.000
#   * research: 0.000
#   * resources: 0.000
#   * revolutionizing: 0.000
#   * rolled: 0.000
#   * safeguard: 0.000
#   * scalability: 0.000
#   * scientists: 0.000
#   * seamless: 0.000
#   * secure: 0.000
#   * sensitive: 0.000
#   * services: 0.000
#   * sets: 0.000
#   * significantly: 0.000
#   * smoothly: 0.000
#   * software: 0.000
#   * soil: 0.000
#   * solutions: 0.000
#   * sources: 0.000
#   * staying: 0.000
#   * storage: 0.000
#   * streamline: 0.000
#   * strive: 0.000
#   * support: 0.000
#   * sustainability: 0.000
#   * sustainable: 0.000
#   * system: 0.000
#   * tasks: 0.000
#   * team: 0.372
#   * techniques: 0.000
#   * technologies: 0.000
#   * technology: 0.000
#   * that: 0.000
#   * the: 0.000
#   * through: 0.000
#   * to: 0.000
#   * top: 0.000
#   * transportation: 0.000
#   * trends: 0.000
#   * update: 0.000
#   * upgrading: 0.000
#   * us: 0.000
#   * user: 0.000
#   * utilize: 0.000
#   * vital: 0.000
#   * vulnerabilities: 0.000
#   * waste: 0.000
#   * water: 0.000
#   * way: 0.000
#   * we: 0.000
#   * webbased: 0.372
#   * with: 0.000
#   * you: 0.000
#   * zero: 0.000
#
# Document 6:
#   * achieve: 0.000
#   * across: 0.000
#   * action: 0.000
#   * actionable: 0.000
#   * adopting: 0.000
#   * agriculture: 0.000
#   * ahead: 0.000
#   * aim: 0.000
#   * aims: 0.000
#   * aipowered: 0.000
#   * air: 0.000
#   * algorithm: 0.000
#   * all: 0.000
#   * amplifies: 0.000
#   * an: 0.000
#   * analytics: 0.000
#   * and: 0.000
#   * applications: 0.000
#   * are: 0.000
#   * at: 0.000
#   * automate: 0.000
#   * awareness: 0.000
#   * better: 0.000
#   * big: 0.000
#   * biodiversity: 0.000
#   * business: 0.000
#   * businesses: 0.000
#   * campaigns: 0.000
#   * can: 0.000
#   * carbon: 0.000
#   * change: 0.000
#   * choices: 0.000
#   * clean: 0.000
#   * climate: 0.000
#   * cloud: 0.000
#   * combating: 0.000
#   * committed: 0.000
#   * communities: 0.000
#   * company: 0.000
#   * complex: 0.000
#   * composting: 0.000
#   * comprehensive: 0.000
#   * computing: 0.000
#   * considered: 0.000
#   * consistently: 0.000
#   * consumption: 0.000
#   * continuous: 0.000
#   * contribute: 0.000
#   * create: 0.000
#   * crucial: 0.000
#   * curve: 0.000
#   * cuttingedge: 0.000
#   * cybersecurity: 0.348
#   * cycles: 0.000
#   * data: 0.246
#   * database: 0.000
#   * decisions: 0.000
#   * delicate: 0.000
#   * delivering: 0.000
#   * deployment: 0.000
#   * design: 0.000
#   * developing: 0.000
#   * development: 0.000
#   * devsecops: 0.000
#   * disruptive: 0.000
#   * drive: 0.000
#   * each: 0.000
#   * ecofriendly: 0.000
#   * ecosystems: 0.000
#   * educate: 0.000
#   * efficient: 0.000
#   * energy: 0.000
#   * enhanced: 0.000
#   * enhancing: 0.000
#   * environment: 0.000
#   * environmental: 0.000
#   * essential: 0.000
#   * excels: 0.000
#   * experience: 0.000
#   * experts: 0.000
#   * extracting: 0.000
#   * facilities: 0.000
#   * flexibility: 0.000
#   * footprint: 0.000
#   * for: 0.000
#   * framework: 0.000
#   * future: 0.000
#   * greener: 0.000
#   * have: 0.000
#   * healthy: 0.000
#   * help: 0.000
#   * impact: 0.000
#   * implementing: 0.000
#   * important: 0.000
#   * in: 0.000
#   * individual: 0.000
#   * infrastructure: 0.000
#   * insights: 0.000
#   * inspire: 0.000
#   * integration: 0.000
#   * interface: 0.000
#   * investing: 0.000
#   * is: 0.000
#   * its: 0.000
#   * key: 0.000
#   * landfill: 0.000
#   * learning: 0.000
#   * legislation: 0.000
#   * machine: 0.000
#   * make: 0.000
#   * measures: 0.348
#   * minimize: 0.000
#   * models: 0.000
#   * monitor: 0.000
#   * natural: 0.000
#   * need: 0.348
#   * network: 0.000
#   * new: 0.000
#   * nourish: 0.000
#   * nutrientrich: 0.000
#   * of: 0.000
#   * offer: 0.000
#   * on: 0.000
#   * operate: 0.000
#   * operations: 0.000
#   * options: 0.000
#   * organization: 0.000
#   * organizations: 0.000
#   * our: 0.000
#   * out: 0.000
#   * part: 0.000
#   * partnering: 0.000
#   * performance: 0.000
#   * planet: 0.000
#   * policy: 0.000
#   * pollution: 0.000
#   * potential: 0.000
#   * power: 0.000
#   * practices: 0.000
#   * prediction: 0.000
#   * prioritize: 0.348
#   * priority: 0.000
#   * processing: 0.000
#   * program: 0.000
#   * programs: 0.000
#   * promoting: 0.000
#   * protect: 0.000
#   * protecting: 0.000
#   * protects: 0.000
#   * providing: 0.000
#   * query: 0.000
#   * recycling: 0.000
#   * reduce: 0.000
#   * reducing: 0.000
#   * release: 0.000
#   * remarkably: 0.000
#   * renewable: 0.000
#   * research: 0.000
#   * resources: 0.000
#   * revolutionizing: 0.000
#   * rolled: 0.000
#   * safeguard: 0.348
#   * scalability: 0.000
#   * scientists: 0.000
#   * seamless: 0.000
#   * secure: 0.000
#   * sensitive: 0.348
#   * services: 0.000
#   * sets: 0.000
#   * significantly: 0.000
#   * smoothly: 0.000
#   * software: 0.000
#   * soil: 0.000
#   * solutions: 0.000
#   * sources: 0.000
#   * staying: 0.000
#   * storage: 0.000
#   * streamline: 0.000
#   * strive: 0.000
#   * support: 0.000
#   * sustainability: 0.000
#   * sustainable: 0.000
#   * system: 0.000
#   * tasks: 0.000
#   * team: 0.000
#   * techniques: 0.000
#   * technologies: 0.000
#   * technology: 0.000
#   * that: 0.000
#   * the: 0.000
#   * through: 0.000
#   * to: 0.379
#   * top: 0.000
#   * transportation: 0.000
#   * trends: 0.000
#   * update: 0.000
#   * upgrading: 0.000
#   * us: 0.000
#   * user: 0.000
#   * utilize: 0.000
#   * vital: 0.000
#   * vulnerabilities: 0.000
#   * waste: 0.000
#   * water: 0.000
#   * way: 0.000
#   * we: 0.263
#   * webbased: 0.000
#   * with: 0.000
#   * you: 0.000
#   * zero: 0.000
#
# Document 7:
#   * achieve: 0.000
#   * across: 0.000
#   * action: 0.000
#   * actionable: 0.000
#   * adopting: 0.000
#   * agriculture: 0.000
#   * ahead: 0.000
#   * aim: 0.000
#   * aims: 0.000
#   * aipowered: 0.317
#   * air: 0.000
#   * algorithm: 0.317
#   * all: 0.000
#   * amplifies: 0.000
#   * an: 0.000
#   * analytics: 0.000
#   * and: 0.000
#   * applications: 0.000
#   * are: 0.000
#   * at: 0.000
#   * automate: 0.000
#   * awareness: 0.000
#   * better: 0.000
#   * big: 0.000
#   * biodiversity: 0.000
#   * business: 0.000
#   * businesses: 0.000
#   * campaigns: 0.000
#   * can: 0.000
#   * carbon: 0.000
#   * change: 0.000
#   * choices: 0.000
#   * clean: 0.000
#   * climate: 0.000
#   * cloud: 0.000
#   * combating: 0.000
#   * committed: 0.000
#   * communities: 0.000
#   * company: 0.000
#   * complex: 0.317
#   * composting: 0.000
#   * comprehensive: 0.000
#   * computing: 0.000
#   * considered: 0.000
#   * consistently: 0.000
#   * consumption: 0.000
#   * continuous: 0.000
#   * contribute: 0.000
#   * create: 0.000
#   * crucial: 0.000
#   * curve: 0.000
#   * cuttingedge: 0.000
#   * cybersecurity: 0.000
#   * cycles: 0.000
#   * data: 0.224
#   * database: 0.000
#   * decisions: 0.000
#   * delicate: 0.000
#   * delivering: 0.000
#   * deployment: 0.000
#   * design: 0.000
#   * developing: 0.000
#   * development: 0.000
#   * devsecops: 0.000
#   * disruptive: 0.000
#   * drive: 0.000
#   * each: 0.000
#   * ecofriendly: 0.000
#   * ecosystems: 0.000
#   * educate: 0.000
#   * efficient: 0.317
#   * energy: 0.000
#   * enhanced: 0.000
#   * enhancing: 0.000
#   * environment: 0.000
#   * environmental: 0.000
#   * essential: 0.000
#   * excels: 0.000
#   * experience: 0.000
#   * experts: 0.000
#   * extracting: 0.000
#   * facilities: 0.000
#   * flexibility: 0.000
#   * footprint: 0.000
#   * for: 0.000
#   * framework: 0.000
#   * future: 0.000
#   * greener: 0.000
#   * have: 0.000
#   * healthy: 0.000
#   * help: 0.000
#   * impact: 0.000
#   * implementing: 0.000
#   * important: 0.000
#   * in: 0.240
#   * individual: 0.000
#   * infrastructure: 0.000
#   * insights: 0.000
#   * inspire: 0.000
#   * integration: 0.000
#   * interface: 0.000
#   * investing: 0.000
#   * is: 0.190
#   * its: 0.000
#   * key: 0.000
#   * landfill: 0.000
#   * learning: 0.000
#   * legislation: 0.000
#   * machine: 0.000
#   * make: 0.000
#   * measures: 0.000
#   * minimize: 0.000
#   * models: 0.000
#   * monitor: 0.000
#   * natural: 0.000
#   * need: 0.000
#   * network: 0.000
#   * new: 0.317
#   * nourish: 0.000
#   * nutrientrich: 0.000
#   * of: 0.000
#   * offer: 0.000
#   * on: 0.000
#   * operate: 0.000
#   * operations: 0.000
#   * options: 0.000
#   * organization: 0.000
#   * organizations: 0.000
#   * our: 0.000
#   * out: 0.000
#   * part: 0.000
#   * partnering: 0.000
#   * performance: 0.000
#   * planet: 0.000
#   * policy: 0.000
#   * pollution: 0.000
#   * potential: 0.000
#   * power: 0.000
#   * practices: 0.000
#   * prediction: 0.000
#   * prioritize: 0.000
#   * priority: 0.000
#   * processing: 0.317
#   * program: 0.000
#   * programs: 0.000
#   * promoting: 0.000
#   * protect: 0.000
#   * protecting: 0.000
#   * protects: 0.000
#   * providing: 0.000
#   * query: 0.000
#   * recycling: 0.000
#   * reduce: 0.000
#   * reducing: 0.000
#   * release: 0.000
#   * remarkably: 0.317
#   * renewable: 0.000
#   * research: 0.000
#   * resources: 0.000
#   * revolutionizing: 0.000
#   * rolled: 0.000
#   * safeguard: 0.000
#   * scalability: 0.000
#   * scientists: 0.000
#   * seamless: 0.000
#   * secure: 0.000
#   * sensitive: 0.000
#   * services: 0.000
#   * sets: 0.317
#   * significantly: 0.000
#   * smoothly: 0.000
#   * software: 0.000
#   * soil: 0.000
#   * solutions: 0.000
#   * sources: 0.000
#   * staying: 0.000
#   * storage: 0.000
#   * streamline: 0.000
#   * strive: 0.000
#   * support: 0.000
#   * sustainability: 0.000
#   * sustainable: 0.000
#   * system: 0.000
#   * tasks: 0.000
#   * team: 0.000
#   * techniques: 0.000
#   * technologies: 0.000
#   * technology: 0.000
#   * that: 0.000
#   * the: 0.224
#   * through: 0.000
#   * to: 0.000
#   * top: 0.000
#   * transportation: 0.000
#   * trends: 0.000
#   * update: 0.000
#   * upgrading: 0.000
#   * us: 0.000
#   * user: 0.000
#   * utilize: 0.000
#   * vital: 0.000
#   * vulnerabilities: 0.000
#   * waste: 0.000
#   * water: 0.000
#   * way: 0.000
#   * we: 0.000
#   * webbased: 0.000
#   * with: 0.000
#   * you: 0.000
#   * zero: 0.000
#
# Document 8:
#   * achieve: 0.000
#   * across: 0.000
#   * action: 0.000
#   * actionable: 0.000
#   * adopting: 0.337
#   * agriculture: 0.000
#   * ahead: 0.000
#   * aim: 0.000
#   * aims: 0.000
#   * aipowered: 0.000
#   * air: 0.000
#   * algorithm: 0.000
#   * all: 0.000
#   * amplifies: 0.000
#   * an: 0.000
#   * analytics: 0.000
#   * and: 0.000
#   * applications: 0.000
#   * are: 0.000
#   * at: 0.000
#   * automate: 0.000
#   * awareness: 0.000
#   * better: 0.000
#   * big: 0.000
#   * biodiversity: 0.000
#   * business: 0.000
#   * businesses: 0.000
#   * campaigns: 0.000
#   * can: 0.000
#   * carbon: 0.000
#   * change: 0.000
#   * choices: 0.000
#   * clean: 0.000
#   * climate: 0.000
#   * cloud: 0.000
#   * combating: 0.000
#   * committed: 0.000
#   * communities: 0.000
#   * company: 0.000
#   * complex: 0.000
#   * composting: 0.000
#   * comprehensive: 0.000
#   * computing: 0.000
#   * considered: 0.337
#   * consistently: 0.000
#   * consumption: 0.000
#   * continuous: 0.000
#   * contribute: 0.000
#   * create: 0.000
#   * crucial: 0.000
#   * curve: 0.000
#   * cuttingedge: 0.000
#   * cybersecurity: 0.000
#   * cycles: 0.000
#   * data: 0.000
#   * database: 0.000
#   * decisions: 0.000
#   * delicate: 0.000
#   * delivering: 0.000
#   * deployment: 0.000
#   * design: 0.000
#   * developing: 0.000
#   * development: 0.300
#   * devsecops: 0.337
#   * disruptive: 0.000
#   * drive: 0.000
#   * each: 0.000
#   * ecofriendly: 0.000
#   * ecosystems: 0.000
#   * educate: 0.000
#   * efficient: 0.000
#   * energy: 0.000
#   * enhanced: 0.000
#   * enhancing: 0.000
#   * environment: 0.000
#   * environmental: 0.000
#   * essential: 0.000
#   * excels: 0.000
#   * experience: 0.000
#   * experts: 0.000
#   * extracting: 0.000
#   * facilities: 0.000
#   * flexibility: 0.000
#   * footprint: 0.000
#   * for: 0.224
#   * framework: 0.337
#   * future: 0.000
#   * greener: 0.000
#   * have: 0.337
#   * healthy: 0.000
#   * help: 0.000
#   * impact: 0.000
#   * implementing: 0.000
#   * important: 0.000
#   * in: 0.000
#   * individual: 0.000
#   * infrastructure: 0.000
#   * insights: 0.000
#   * inspire: 0.000
#   * integration: 0.000
#   * interface: 0.000
#   * investing: 0.000
#   * is: 0.000
#   * its: 0.000
#   * key: 0.000
#   * landfill: 0.000
#   * learning: 0.000
#   * legislation: 0.000
#   * machine: 0.000
#   * make: 0.000
#   * measures: 0.000
#   * minimize: 0.000
#   * models: 0.000
#   * monitor: 0.000
#   * natural: 0.000
#   * need: 0.000
#   * network: 0.000
#   * new: 0.000
#   * nourish: 0.000
#   * nutrientrich: 0.000
#   * of: 0.000
#   * offer: 0.000
#   * on: 0.000
#   * operate: 0.000
#   * operations: 0.000
#   * options: 0.000
#   * organization: 0.000
#   * organizations: 0.000
#   * our: 0.000
#   * out: 0.000
#   * part: 0.000
#   * partnering: 0.000
#   * performance: 0.000
#   * planet: 0.000
#   * policy: 0.000
#   * pollution: 0.000
#   * potential: 0.000
#   * power: 0.000
#   * practices: 0.000
#   * prediction: 0.000
#   * prioritize: 0.000
#   * priority: 0.000
#   * processing: 0.000
#   * program: 0.000
#   * programs: 0.000
#   * promoting: 0.000
#   * protect: 0.000
#   * protecting: 0.000
#   * protects: 0.000
#   * providing: 0.000
#   * query: 0.000
#   * recycling: 0.000
#   * reduce: 0.000
#   * reducing: 0.000
#   * release: 0.000
#   * remarkably: 0.000
#   * renewable: 0.000
#   * research: 0.000
#   * resources: 0.000
#   * revolutionizing: 0.000
#   * rolled: 0.000
#   * safeguard: 0.000
#   * scalability: 0.000
#   * scientists: 0.000
#   * seamless: 0.000
#   * secure: 0.337
#   * sensitive: 0.000
#   * services: 0.000
#   * sets: 0.000
#   * significantly: 0.000
#   * smoothly: 0.000
#   * software: 0.254
#   * soil: 0.000
#   * solutions: 0.000
#   * sources: 0.000
#   * staying: 0.000
#   * storage: 0.000
#   * streamline: 0.000
#   * strive: 0.000
#   * support: 0.000
#   * sustainability: 0.000
#   * sustainable: 0.000
#   * system: 0.000
#   * tasks: 0.000
#   * team: 0.000
#   * techniques: 0.000
#   * technologies: 0.000
#   * technology: 0.000
#   * that: 0.000
#   * the: 0.000
#   * through: 0.000
#   * to: 0.000
#   * top: 0.000
#   * transportation: 0.000
#   * trends: 0.000
#   * update: 0.000
#   * upgrading: 0.000
#   * us: 0.000
#   * user: 0.000
#   * utilize: 0.000
#   * vital: 0.000
#   * vulnerabilities: 0.000
#   * waste: 0.000
#   * water: 0.000
#   * way: 0.000
#   * we: 0.000
#   * webbased: 0.000
#   * with: 0.000
#   * you: 0.337
#   * zero: 0.000
#
# Document 9:
#   * achieve: 0.000
#   * across: 0.000
#   * action: 0.000
#   * actionable: 0.000
#   * adopting: 0.000
#   * agriculture: 0.000
#   * ahead: 0.000
#   * aim: 0.000
#   * aims: 0.000
#   * aipowered: 0.000
#   * air: 0.000
#   * algorithm: 0.000
#   * all: 0.000
#   * amplifies: 0.000
#   * an: 0.000
#   * analytics: 0.000
#   * and: 0.000
#   * applications: 0.000
#   * are: 0.000
#   * at: 0.000
#   * automate: 0.000
#   * awareness: 0.000
#   * better: 0.000
#   * big: 0.000
#   * biodiversity: 0.000
#   * business: 0.000
#   * businesses: 0.000
#   * campaigns: 0.000
#   * can: 0.000
#   * carbon: 0.000
#   * change: 0.000
#   * choices: 0.000
#   * clean: 0.000
#   * climate: 0.000
#   * cloud: 0.000
#   * combating: 0.000
#   * committed: 0.000
#   * communities: 0.000
#   * company: 0.000
#   * complex: 0.000
#   * composting: 0.000
#   * comprehensive: 0.000
#   * computing: 0.000
#   * considered: 0.000
#   * consistently: 0.372
#   * consumption: 0.000
#   * continuous: 0.000
#   * contribute: 0.000
#   * create: 0.000
#   * crucial: 0.000
#   * curve: 0.000
#   * cuttingedge: 0.000
#   * cybersecurity: 0.000
#   * cycles: 0.000
#   * data: 0.000
#   * database: 0.000
#   * decisions: 0.000
#   * delicate: 0.000
#   * delivering: 0.000
#   * deployment: 0.000
#   * design: 0.000
#   * developing: 0.000
#   * development: 0.000
#   * devsecops: 0.000
#   * disruptive: 0.000
#   * drive: 0.000
#   * each: 0.000
#   * ecofriendly: 0.000
#   * ecosystems: 0.000
#   * educate: 0.000
#   * efficient: 0.000
#   * energy: 0.000
#   * enhanced: 0.000
#   * enhancing: 0.000
#   * environment: 0.000
#   * environmental: 0.000
#   * essential: 0.000
#   * excels: 0.000
#   * experience: 0.000
#   * experts: 0.000
#   * extracting: 0.000
#   * facilities: 0.000
#   * flexibility: 0.000
#   * footprint: 0.000
#   * for: 0.247
#   * framework: 0.000
#   * future: 0.000
#   * greener: 0.000
#   * have: 0.000
#   * healthy: 0.000
#   * help: 0.000
#   * impact: 0.000
#   * implementing: 0.000
#   * important: 0.000
#   * in: 0.000
#   * individual: 0.000
#   * infrastructure: 0.372
#   * insights: 0.000
#   * inspire: 0.000
#   * integration: 0.000
#   * interface: 0.000
#   * investing: 0.000
#   * is: 0.000
#   * its: 0.000
#   * key: 0.000
#   * landfill: 0.000
#   * learning: 0.000
#   * legislation: 0.000
#   * machine: 0.000
#   * make: 0.000
#   * measures: 0.000
#   * minimize: 0.000
#   * models: 0.000
#   * monitor: 0.372
#   * natural: 0.000
#   * need: 0.000
#   * network: 0.372
#   * new: 0.000
#   * nourish: 0.000
#   * nutrientrich: 0.000
#   * of: 0.000
#   * offer: 0.000
#   * on: 0.000
#   * operate: 0.000
#   * operations: 0.000
#   * options: 0.000
#   * organization: 0.000
#   * organizations: 0.000
#   * our: 0.178
#   * out: 0.000
#   * part: 0.000
#   * partnering: 0.000
#   * performance: 0.000
#   * planet: 0.000
#   * policy: 0.000
#   * pollution: 0.000
#   * potential: 0.372
#   * power: 0.000
#   * practices: 0.000
#   * prediction: 0.000
#   * prioritize: 0.000
#   * priority: 0.000
#   * processing: 0.000
#   * program: 0.000
#   * programs: 0.000
#   * promoting: 0.000
#   * protect: 0.000
#   * protecting: 0.000
#   * protects: 0.000
#   * providing: 0.000
#   * query: 0.000
#   * recycling: 0.000
#   * reduce: 0.000
#   * reducing: 0.000
#   * release: 0.000
#   * remarkably: 0.000
#   * renewable: 0.000
#   * research: 0.000
#   * resources: 0.000
#   * revolutionizing: 0.000
#   * rolled: 0.000
#   * safeguard: 0.000
#   * scalability: 0.000
#   * scientists: 0.000
#   * seamless: 0.000
#   * secure: 0.000
#   * sensitive: 0.000
#   * services: 0.000
#   * sets: 0.000
#   * significantly: 0.000
#   * smoothly: 0.000
#   * software: 0.000
#   * soil: 0.000
#   * solutions: 0.000
#   * sources: 0.000
#   * staying: 0.000
#   * storage: 0.000
#   * streamline: 0.000
#   * strive: 0.000
#   * support: 0.000
#   * sustainability: 0.000
#   * sustainable: 0.000
#   * system: 0.000
#   * tasks: 0.000
#   * team: 0.000
#   * techniques: 0.000
#   * technologies: 0.000
#   * technology: 0.000
#   * that: 0.000
#   * the: 0.000
#   * through: 0.000
#   * to: 0.000
#   * top: 0.000
#   * transportation: 0.000
#   * trends: 0.000
#   * update: 0.000
#   * upgrading: 0.000
#   * us: 0.000
#   * user: 0.000
#   * utilize: 0.000
#   * vital: 0.000
#   * vulnerabilities: 0.372
#   * waste: 0.000
#   * water: 0.000
#   * way: 0.000
#   * we: 0.281
#   * webbased: 0.000
#   * with: 0.000
#   * you: 0.000
#   * zero: 0.000
#
# Document 10:
#   * achieve: 0.000
#   * across: 0.000
#   * action: 0.000
#   * actionable: 0.000
#   * adopting: 0.000
#   * agriculture: 0.000
#   * ahead: 0.000
#   * aim: 0.000
#   * aims: 0.000
#   * aipowered: 0.000
#   * air: 0.000
#   * algorithm: 0.000
#   * all: 0.000
#   * amplifies: 0.000
#   * an: 0.000
#   * analytics: 0.000
#   * and: 0.247
#   * applications: 0.000
#   * are: 0.000
#   * at: 0.000
#   * automate: 0.000
#   * awareness: 0.000
#   * better: 0.000
#   * big: 0.000
#   * biodiversity: 0.000
#   * business: 0.000
#   * businesses: 0.000
#   * campaigns: 0.000
#   * can: 0.000
#   * carbon: 0.000
#   * change: 0.000
#   * choices: 0.000
#   * clean: 0.000
#   * climate: 0.000
#   * cloud: 0.000
#   * combating: 0.000
#   * committed: 0.000
#   * communities: 0.000
#   * company: 0.000
#   * complex: 0.000
#   * composting: 0.000
#   * comprehensive: 0.000
#   * computing: 0.000
#   * considered: 0.000
#   * consistently: 0.000
#   * consumption: 0.000
#   * continuous: 0.372
#   * contribute: 0.000
#   * create: 0.000
#   * crucial: 0.000
#   * curve: 0.000
#   * cuttingedge: 0.000
#   * cybersecurity: 0.000
#   * cycles: 0.372
#   * data: 0.000
#   * database: 0.000
#   * decisions: 0.000
#   * delicate: 0.000
#   * delivering: 0.000
#   * deployment: 0.372
#   * design: 0.000
#   * developing: 0.000
#   * development: 0.000
#   * devsecops: 0.000
#   * disruptive: 0.000
#   * drive: 0.000
#   * each: 0.000
#   * ecofriendly: 0.000
#   * ecosystems: 0.000
#   * educate: 0.000
#   * efficient: 0.000
#   * energy: 0.000
#   * enhanced: 0.000
#   * enhancing: 0.000
#   * environment: 0.000
#   * environmental: 0.000
#   * essential: 0.000
#   * excels: 0.000
#   * experience: 0.000
#   * experts: 0.000
#   * extracting: 0.000
#   * facilities: 0.000
#   * flexibility: 0.000
#   * footprint: 0.000
#   * for: 0.000
#   * framework: 0.000
#   * future: 0.000
#   * greener: 0.000
#   * have: 0.000
#   * healthy: 0.000
#   * help: 0.000
#   * impact: 0.000
#   * implementing: 0.000
#   * important: 0.000
#   * in: 0.000
#   * individual: 0.000
#   * infrastructure: 0.000
#   * insights: 0.000
#   * inspire: 0.000
#   * integration: 0.372
#   * interface: 0.000
#   * investing: 0.000
#   * is: 0.000
#   * its: 0.000
#   * key: 0.000
#   * landfill: 0.000
#   * learning: 0.000
#   * legislation: 0.000
#   * machine: 0.000
#   * make: 0.000
#   * measures: 0.000
#   * minimize: 0.000
#   * models: 0.000
#   * monitor: 0.000
#   * natural: 0.000
#   * need: 0.000
#   * network: 0.000
#   * new: 0.000
#   * nourish: 0.000
#   * nutrientrich: 0.000
#   * of: 0.000
#   * offer: 0.000
#   * on: 0.000
#   * operate: 0.000
#   * operations: 0.000
#   * options: 0.000
#   * organization: 0.000
#   * organizations: 0.000
#   * our: 0.178
#   * out: 0.000
#   * part: 0.000
#   * partnering: 0.000
#   * performance: 0.000
#   * planet: 0.000
#   * policy: 0.000
#   * pollution: 0.000
#   * potential: 0.000
#   * power: 0.000
#   * practices: 0.000
#   * prediction: 0.000
#   * prioritize: 0.000
#   * priority: 0.000
#   * processing: 0.000
#   * program: 0.000
#   * programs: 0.000
#   * promoting: 0.000
#   * protect: 0.000
#   * protecting: 0.000
#   * protects: 0.000
#   * providing: 0.000
#   * query: 0.000
#   * recycling: 0.000
#   * reduce: 0.000
#   * reducing: 0.000
#   * release: 0.372
#   * remarkably: 0.000
#   * renewable: 0.000
#   * research: 0.000
#   * resources: 0.000
#   * revolutionizing: 0.000
#   * rolled: 0.000
#   * safeguard: 0.000
#   * scalability: 0.000
#   * scientists: 0.000
#   * seamless: 0.000
#   * secure: 0.000
#   * sensitive: 0.000
#   * services: 0.000
#   * sets: 0.000
#   * significantly: 0.000
#   * smoothly: 0.000
#   * software: 0.281
#   * soil: 0.000
#   * solutions: 0.000
#   * sources: 0.000
#   * staying: 0.000
#   * storage: 0.000
#   * streamline: 0.372
#   * strive: 0.000
#   * support: 0.000
#   * sustainability: 0.000
#   * sustainable: 0.000
#   * system: 0.000
#   * tasks: 0.000
#   * team: 0.000
#   * techniques: 0.000
#   * technologies: 0.000
#   * technology: 0.000
#   * that: 0.000
#   * the: 0.000
#   * through: 0.000
#   * to: 0.000
#   * top: 0.000
#   * transportation: 0.000
#   * trends: 0.000
#   * update: 0.000
#   * upgrading: 0.000
#   * us: 0.000
#   * user: 0.000
#   * utilize: 0.000
#   * vital: 0.000
#   * vulnerabilities: 0.000
#   * waste: 0.000
#   * water: 0.000
#   * way: 0.000
#   * we: 0.000
#   * webbased: 0.000
#   * with: 0.000
#   * you: 0.000
#   * zero: 0.000
#
# Document 11:
#   * achieve: 0.000
#   * across: 0.000
#   * action: 0.000
#   * actionable: 0.000
#   * adopting: 0.000
#   * agriculture: 0.000
#   * ahead: 0.000
#   * aim: 0.000
#   * aims: 0.000
#   * aipowered: 0.000
#   * air: 0.000
#   * algorithm: 0.000
#   * all: 0.000
#   * amplifies: 0.000
#   * an: 0.000
#   * analytics: 0.000
#   * and: 0.000
#   * applications: 0.000
#   * are: 0.000
#   * at: 0.000
#   * automate: 0.000
#   * awareness: 0.000
#   * better: 0.000
#   * big: 0.000
#   * biodiversity: 0.000
#   * business: 0.000
#   * businesses: 0.000
#   * campaigns: 0.000
#   * can: 0.000
#   * carbon: 0.000
#   * change: 0.000
#   * choices: 0.000
#   * clean: 0.000
#   * climate: 0.000
#   * cloud: 0.000
#   * combating: 0.000
#   * committed: 0.000
#   * communities: 0.000
#   * company: 0.000
#   * complex: 0.000
#   * composting: 0.000
#   * comprehensive: 0.000
#   * computing: 0.000
#   * considered: 0.000
#   * consistently: 0.000
#   * consumption: 0.000
#   * continuous: 0.000
#   * contribute: 0.000
#   * create: 0.000
#   * crucial: 0.000
#   * curve: 0.000
#   * cuttingedge: 0.000
#   * cybersecurity: 0.000
#   * cycles: 0.000
#   * data: 0.000
#   * database: 0.377
#   * decisions: 0.000
#   * delicate: 0.000
#   * delivering: 0.000
#   * deployment: 0.000
#   * design: 0.000
#   * developing: 0.000
#   * development: 0.000
#   * devsecops: 0.000
#   * disruptive: 0.000
#   * drive: 0.000
#   * each: 0.000
#   * ecofriendly: 0.000
#   * ecosystems: 0.000
#   * educate: 0.000
#   * efficient: 0.000
#   * energy: 0.000
#   * enhanced: 0.377
#   * enhancing: 0.000
#   * environment: 0.000
#   * environmental: 0.000
#   * essential: 0.000
#   * excels: 0.000
#   * experience: 0.000
#   * experts: 0.000
#   * extracting: 0.000
#   * facilities: 0.000
#   * flexibility: 0.000
#   * footprint: 0.000
#   * for: 0.000
#   * framework: 0.000
#   * future: 0.000
#   * greener: 0.000
#   * have: 0.000
#   * healthy: 0.000
#   * help: 0.000
#   * impact: 0.000
#   * implementing: 0.000
#   * important: 0.000
#   * in: 0.000
#   * individual: 0.000
#   * infrastructure: 0.000
#   * insights: 0.000
#   * inspire: 0.000
#   * integration: 0.000
#   * interface: 0.000
#   * investing: 0.000
#   * is: 0.000
#   * its: 0.000
#   * key: 0.000
#   * landfill: 0.000
#   * learning: 0.000
#   * legislation: 0.000
#   * machine: 0.000
#   * make: 0.000
#   * measures: 0.000
#   * minimize: 0.000
#   * models: 0.000
#   * monitor: 0.000
#   * natural: 0.000
#   * need: 0.000
#   * network: 0.000
#   * new: 0.000
#   * nourish: 0.000
#   * nutrientrich: 0.000
#   * of: 0.000
#   * offer: 0.000
#   * on: 0.000
#   * operate: 0.000
#   * operations: 0.000
#   * options: 0.000
#   * organization: 0.000
#   * organizations: 0.000
#   * our: 0.181
#   * out: 0.000
#   * part: 0.000
#   * partnering: 0.000
#   * performance: 0.377
#   * planet: 0.000
#   * policy: 0.000
#   * pollution: 0.000
#   * potential: 0.000
#   * power: 0.000
#   * practices: 0.000
# ...
#   * business: 0.000
#   * businesses: 0.000
#   * campaigns: 0.000
#   * can: 0.000
#   * carbon: 0.000
#   * change: 0.000
#   * choices: 0.000
#   * clean: 0.000
#   * climate: 0.000
#   * cloud: 0.000
#   * combating: 0.000
#   * committed: 0.000
#   * communities: 0.000
#   * company: 0.000
#   * complex: 0.000
#   * composting: 0.000
#   * comprehensive: 0.000
#   * computing: 0.000
#   * considered: 0.000
#   * consistently: 0.000
#   * consumption: 0.000
#   * continuous: 0.000
#   * contribute: 0.000
#   * create: 0.000
#   * crucial: 0.000
#   * curve: 0.000
#   * cuttingedge: 0.000
#   * cybersecurity: 0.000
#   * cycles: 0.000
#   * data: 0.000
#   * database: 0.000
#   * decisions: 0.000
#   * delicate: 0.381
#   * delivering: 0.000
#   * deployment: 0.000
#   * design: 0.000
#   * developing: 0.000
#   * development: 0.000
#   * devsecops: 0.000
#   * disruptive: 0.000
#   * drive: 0.000
#   * each: 0.000
#   * ecofriendly: 0.000
#   * ecosystems: 0.381
#   * educate: 0.000
#   * efficient: 0.000
#   * energy: 0.000
#   * enhanced: 0.000
#   * enhancing: 0.000
#   * environment: 0.000
#   * environmental: 0.000
#   * essential: 0.000
#   * excels: 0.000
#   * experience: 0.000
#   * experts: 0.000
#   * extracting: 0.000
#   * facilities: 0.000
#   * flexibility: 0.000
#   * footprint: 0.000
#   * for: 0.000
#   * framework: 0.000
#   * future: 0.000
#   * greener: 0.000
#   * have: 0.000
#   * healthy: 0.000
#   * help: 0.000
#   * impact: 0.340
#   * implementing: 0.000
#   * important: 0.000
#   * in: 0.000
#   * individual: 0.000
#   * infrastructure: 0.000
#   * insights: 0.000
#   * inspire: 0.000
#   * integration: 0.000
#   * interface: 0.000
#   * investing: 0.000
#   * is: 0.000
#   * its: 0.000
#   * key: 0.000
#   * landfill: 0.000
#   * learning: 0.000
#   * legislation: 0.000
#   * machine: 0.000
#   * make: 0.000
#   * measures: 0.000
#   * minimize: 0.381
#   * models: 0.000
#   * monitor: 0.000
#   * natural: 0.000
#   * need: 0.000
#   * network: 0.000
#   * new: 0.000
#   * nourish: 0.000
#   * nutrientrich: 0.000
#   * of: 0.000
#   * offer: 0.000
#   * on: 0.381
#   * operate: 0.000
#   * operations: 0.000
#   * options: 0.000
#   * organization: 0.000
#   * organizations: 0.000
#   * our: 0.183
#   * out: 0.000
#   * part: 0.000
#   * partnering: 0.000
#   * performance: 0.000
#   * planet: 0.000
#   * policy: 0.000
#   * pollution: 0.000
#   * potential: 0.000
#   * power: 0.000
#   * practices: 0.000
#   * prediction: 0.000
#   * prioritize: 0.000
#   * priority: 0.000
#   * processing: 0.000
#   * program: 0.000
#   * programs: 0.000
#   * promoting: 0.000
#   * protect: 0.000
#   * protecting: 0.000
#   * protects: 0.000
#   * providing: 0.000
#   * query: 0.000
#   * recycling: 0.000
#   * reduce: 0.000
#   * reducing: 0.000
#   * release: 0.000
#   * remarkably: 0.000
#   * renewable: 0.000
#   * research: 0.000
#   * resources: 0.000
#   * revolutionizing: 0.000
#   * rolled: 0.000
#   * safeguard: 0.000
#   * scalability: 0.000
#   * scientists: 0.000
#   * seamless: 0.000
#   * secure: 0.000
#   * sensitive: 0.000
#   * services: 0.000
#   * sets: 0.000
#   * significantly: 0.000
#   * smoothly: 0.000
#   * software: 0.000
#   * soil: 0.000
#   * solutions: 0.000
#   * sources: 0.000
#   * staying: 0.000
#   * storage: 0.000
#   * streamline: 0.000
#   * strive: 0.381
#   * support: 0.000
#   * sustainability: 0.000
#   * sustainable: 0.000
#   * system: 0.000
#   * tasks: 0.000
#   * team: 0.000
#   * techniques: 0.000
#   * technologies: 0.000
#   * technology: 0.000
#   * that: 0.000
#   * the: 0.000
#   * through: 0.000
#   * to: 0.207
#   * top: 0.000
#   * transportation: 0.000
#   * trends: 0.000
#   * update: 0.000
#   * upgrading: 0.000
#   * us: 0.000
#   * user: 0.000
#   * utilize: 0.000
#   * vital: 0.000
#   * vulnerabilities: 0.000
#   * waste: 0.000
#   * water: 0.000
#   * way: 0.000
#   * we: 0.288
#   * webbased: 0.000
#   * with: 0.000
#   * you: 0.000
#   * zero: 0.000
#
# Document 27:
#   * achieve: 0.000
#   * across: 0.000
#   * action: 0.000
#   * actionable: 0.000
#   * adopting: 0.000
#   * agriculture: 0.000
#   * ahead: 0.000
#   * aim: 0.000
#   * aims: 0.000
#   * aipowered: 0.000
#   * air: 0.000
#   * algorithm: 0.000
#   * all: 0.000
#   * amplifies: 0.000
#   * an: 0.000
#   * analytics: 0.000
#   * and: 0.000
#   * applications: 0.000
#   * are: 0.000
#   * at: 0.000
#   * automate: 0.000
#   * awareness: 0.000
#   * better: 0.000
#   * big: 0.000
#   * biodiversity: 0.000
#   * business: 0.000
#   * businesses: 0.000
#   * campaigns: 0.000
#   * can: 0.000
#   * carbon: 0.000
#   * change: 0.000
#   * choices: 0.000
#   * clean: 0.000
#   * climate: 0.000
#   * cloud: 0.000
#   * combating: 0.000
#   * committed: 0.000
#   * communities: 0.000
#   * company: 0.000
#   * complex: 0.000
#   * composting: 0.000
#   * comprehensive: 0.000
#   * computing: 0.000
#   * considered: 0.000
#   * consistently: 0.000
#   * consumption: 0.000
#   * continuous: 0.000
#   * contribute: 0.000
#   * create: 0.000
#   * crucial: 0.000
#   * curve: 0.000
#   * cuttingedge: 0.000
#   * cybersecurity: 0.000
#   * cycles: 0.000
#   * data: 0.000
#   * database: 0.000
#   * decisions: 0.000
#   * delicate: 0.000
#   * delivering: 0.000
#   * deployment: 0.000
#   * design: 0.000
#   * developing: 0.000
#   * development: 0.000
#   * devsecops: 0.000
#   * disruptive: 0.000
#   * drive: 0.000
#   * each: 0.000
#   * ecofriendly: 0.000
#   * ecosystems: 0.000
#   * educate: 0.000
#   * efficient: 0.000
#   * energy: 0.000
#   * enhanced: 0.000
#   * enhancing: 0.000
#   * environment: 0.000
#   * environmental: 0.255
#   * essential: 0.338
#   * excels: 0.000
#   * experience: 0.000
#   * experts: 0.000
#   * extracting: 0.000
#   * facilities: 0.000
#   * flexibility: 0.000
#   * footprint: 0.000
#   * for: 0.000
#   * framework: 0.000
#   * future: 0.000
#   * greener: 0.000
#   * have: 0.000
#   * healthy: 0.000
#   * help: 0.000
#   * impact: 0.000
#   * implementing: 0.000
#   * important: 0.000
#   * in: 0.000
#   * individual: 0.000
#   * infrastructure: 0.000
#   * insights: 0.000
#   * inspire: 0.000
#   * integration: 0.000
#   * interface: 0.000
#   * investing: 0.000
#   * is: 0.000
#   * its: 0.338
#   * key: 0.000
#   * landfill: 0.000
#   * learning: 0.000
#   * legislation: 0.338
#   * machine: 0.000
#   * make: 0.000
#   * measures: 0.000
#   * minimize: 0.000
#   * models: 0.000
#   * monitor: 0.000
#   * natural: 0.338
#   * need: 0.000
#   * network: 0.000
#   * new: 0.000
#   * nourish: 0.000
#   * nutrientrich: 0.000
#   * of: 0.000
#   * offer: 0.000
#   * on: 0.000
#   * operate: 0.000
#   * operations: 0.000
#   * options: 0.000
#   * organization: 0.000
#   * organizations: 0.000
#   * our: 0.162
#   * out: 0.000
#   * part: 0.000
#   * partnering: 0.000
#   * performance: 0.000
#   * planet: 0.000
#   * policy: 0.000
#   * pollution: 0.000
#   * potential: 0.000
#   * power: 0.000
#   * practices: 0.000
#   * prediction: 0.000
#   * prioritize: 0.000
#   * priority: 0.000
#   * processing: 0.000
#   * program: 0.000
#   * programs: 0.000
#   * promoting: 0.000
#   * protect: 0.000
#   * protecting: 0.000
#   * protects: 0.338
#   * providing: 0.000
#   * query: 0.000
#   * recycling: 0.000
#   * reduce: 0.000
#   * reducing: 0.000
#   * release: 0.000
#   * remarkably: 0.000
#   * renewable: 0.000
#   * research: 0.000
#   * resources: 0.338
#   * revolutionizing: 0.000
#   * rolled: 0.000
#   * safeguard: 0.000
#   * scalability: 0.000
#   * scientists: 0.000
#   * seamless: 0.000
#   * secure: 0.000
#   * sensitive: 0.000
#   * services: 0.000
#   * sets: 0.000
#   * significantly: 0.000
#   * smoothly: 0.000
#   * software: 0.000
#   * soil: 0.000
#   * solutions: 0.000
#   * sources: 0.000
#   * staying: 0.000
#   * storage: 0.000
#   * streamline: 0.000
#   * strive: 0.000
#   * support: 0.338
#   * sustainability: 0.000
#   * sustainable: 0.000
#   * system: 0.000
#   * tasks: 0.000
#   * team: 0.000
#   * techniques: 0.000
#   * technologies: 0.000
#   * technology: 0.000
#   * that: 0.275
#   * the: 0.000
#   * through: 0.000
#   * to: 0.184
#   * top: 0.000
#   * transportation: 0.000
#   * trends: 0.000
#   * update: 0.000
#   * upgrading: 0.000
#   * us: 0.000
#   * user: 0.000
#   * utilize: 0.000
#   * vital: 0.000
#   * vulnerabilities: 0.000
#   * waste: 0.000
#   * water: 0.000
#   * way: 0.000
#   * we: 0.000
#   * webbased: 0.000
#   * with: 0.000
#   * you: 0.000
#   * zero: 0.000
#
# Document 28:
#   * achieve: 0.000
#   * across: 0.000
#   * action: 0.000
#   * actionable: 0.000
#   * adopting: 0.000
#   * agriculture: 0.000
#   * ahead: 0.000
#   * aim: 0.000
#   * aims: 0.000
#   * aipowered: 0.000
#   * air: 0.363
#   * algorithm: 0.000
#   * all: 0.000
#   * amplifies: 0.000
#   * an: 0.000
#   * analytics: 0.000
#   * and: 0.000
#   * applications: 0.000
#   * are: 0.000
#   * at: 0.000
#   * automate: 0.000
#   * awareness: 0.000
#   * better: 0.000
#   * big: 0.000
#   * biodiversity: 0.000
#   * business: 0.000
#   * businesses: 0.000
#   * campaigns: 0.000
#   * can: 0.324
#   * carbon: 0.000
#   * change: 0.000
#   * choices: 0.000
#   * clean: 0.000
#   * climate: 0.000
#   * cloud: 0.000
#   * combating: 0.000
#   * committed: 0.000
#   * communities: 0.000
#   * company: 0.000
#   * complex: 0.000
#   * composting: 0.000
#   * comprehensive: 0.000
#   * computing: 0.000
#   * considered: 0.000
#   * consistently: 0.000
#   * consumption: 0.000
#   * continuous: 0.000
#   * contribute: 0.000
#   * create: 0.000
#   * crucial: 0.000
#   * curve: 0.000
#   * cuttingedge: 0.000
#   * cybersecurity: 0.000
#   * cycles: 0.000
#   * data: 0.000
#   * database: 0.000
#   * decisions: 0.000
#   * delicate: 0.000
#   * delivering: 0.000
#   * deployment: 0.000
#   * design: 0.000
#   * developing: 0.000
#   * development: 0.000
#   * devsecops: 0.000
#   * disruptive: 0.000
#   * drive: 0.000
#   * each: 0.000
#   * ecofriendly: 0.363
#   * ecosystems: 0.000
#   * educate: 0.000
#   * efficient: 0.000
#   * energy: 0.000
#   * enhanced: 0.000
#   * enhancing: 0.000
#   * environment: 0.000
#   * environmental: 0.000
#   * essential: 0.000
#   * excels: 0.000
#   * experience: 0.000
#   * experts: 0.000
#   * extracting: 0.000
#   * facilities: 0.000
#   * flexibility: 0.000
#   * footprint: 0.000
#   * for: 0.000
#   * framework: 0.000
#   * future: 0.000
#   * greener: 0.000
#   * have: 0.000
#   * healthy: 0.000
#   * help: 0.000
#   * impact: 0.000
#   * implementing: 0.000
#   * important: 0.000
#   * in: 0.000
#   * individual: 0.000
#   * infrastructure: 0.000
#   * insights: 0.000
#   * inspire: 0.000
#   * integration: 0.000
#   * interface: 0.000
#   * investing: 0.000
#   * is: 0.000
#   * its: 0.000
#   * key: 0.000
#   * landfill: 0.000
#   * learning: 0.000
#   * legislation: 0.000
#   * machine: 0.000
#   * make: 0.000
#   * measures: 0.000
#   * minimize: 0.000
#   * models: 0.000
#   * monitor: 0.000
#   * natural: 0.000
#   * need: 0.000
#   * network: 0.000
#   * new: 0.000
#   * nourish: 0.000
#   * nutrientrich: 0.000
#   * of: 0.000
#   * offer: 0.000
#   * on: 0.000
#   * operate: 0.000
#   * operations: 0.000
#   * options: 0.363
#   * organization: 0.000
#   * organizations: 0.000
#   * our: 0.000
#   * out: 0.000
#   * part: 0.000
#   * partnering: 0.000
#   * performance: 0.000
#   * planet: 0.000
#   * policy: 0.000
#   * pollution: 0.363
#   * potential: 0.000
#   * power: 0.000
#   * practices: 0.000
#   * prediction: 0.000
#   * prioritize: 0.000
#   * priority: 0.000
#   * processing: 0.000
#   * program: 0.000
#   * programs: 0.000
#   * promoting: 0.363
#   * protect: 0.000
#   * protecting: 0.000
#   * protects: 0.000
#   * providing: 0.000
#   * query: 0.000
#   * recycling: 0.000
#   * reduce: 0.324
#   * reducing: 0.000
#   * release: 0.000
#   * remarkably: 0.000
#   * renewable: 0.000
#   * research: 0.000
#   * resources: 0.000
#   * revolutionizing: 0.000
#   * rolled: 0.000
#   * safeguard: 0.000
#   * scalability: 0.000
#   * scientists: 0.000
#   * seamless: 0.000
#   * secure: 0.000
#   * sensitive: 0.000
#   * services: 0.000
#   * sets: 0.000
#   * significantly: 0.000
#   * smoothly: 0.000
#   * software: 0.000
#   * soil: 0.000
#   * solutions: 0.000
#   * sources: 0.000
#   * staying: 0.000
#   * storage: 0.000
#   * streamline: 0.000
#   * strive: 0.000
#   * support: 0.000
#   * sustainability: 0.000
#   * sustainable: 0.000
#   * system: 0.000
#   * tasks: 0.000
#   * team: 0.000
#   * techniques: 0.000
#   * technologies: 0.000
#   * technology: 0.000
#   * that: 0.000
#   * the: 0.000
#   * through: 0.000
#   * to: 0.000
#   * top: 0.000
#   * transportation: 0.363
#   * trends: 0.000
#   * update: 0.000
#   * upgrading: 0.000
#   * us: 0.000
#   * user: 0.000
#   * utilize: 0.000
#   * vital: 0.000
#   * vulnerabilities: 0.000
#   * waste: 0.000
#   * water: 0.000
#   * way: 0.000
#   * we: 0.000
#   * webbased: 0.000
#   * with: 0.000
#   * you: 0.000
#   * zero: 0.000
#
# Document 29:
#   * achieve: 0.000
#   * across: 0.000
#   * action: 0.000
#   * actionable: 0.000
#   * adopting: 0.000
#   * agriculture: 0.000
#   * ahead: 0.000
#   * aim: 0.000
#   * aims: 0.000
#   * aipowered: 0.000
#   * air: 0.000
#   * algorithm: 0.000
#   * all: 0.000
#   * amplifies: 0.000
#   * an: 0.000
#   * analytics: 0.000
#   * and: 0.000
#   * applications: 0.000
#   * are: 0.000
#   * at: 0.000
#   * automate: 0.000
#   * awareness: 0.000
#   * better: 0.000
#   * big: 0.000
#   * biodiversity: 0.000
#   * business: 0.000
#   * businesses: 0.000
#   * campaigns: 0.000
#   * can: 0.301
#   * carbon: 0.000
#   * change: 0.000
#   * choices: 0.338
#   * clean: 0.000
#   * climate: 0.000
#   * cloud: 0.000
#   * combating: 0.000
#   * committed: 0.000
#   * communities: 0.000
#   * company: 0.000
#   * complex: 0.000
#   * composting: 0.000
#   * comprehensive: 0.000
#   * computing: 0.000
#   * considered: 0.000
#   * consistently: 0.000
#   * consumption: 0.000
#   * continuous: 0.000
#   * contribute: 0.338
#   * create: 0.000
#   * crucial: 0.000
#   * curve: 0.000
#   * cuttingedge: 0.000
#   * cybersecurity: 0.000
#   * cycles: 0.000
#   * data: 0.000
#   * database: 0.000
#   * decisions: 0.000
#   * delicate: 0.000
#   * delivering: 0.000
#   * deployment: 0.000
#   * design: 0.000
#   * developing: 0.000
#   * development: 0.000
#   * devsecops: 0.000
#   * disruptive: 0.000
#   * drive: 0.000
#   * each: 0.338
#   * ecofriendly: 0.000
#   * ecosystems: 0.000
#   * educate: 0.000
#   * efficient: 0.000
#   * energy: 0.000
#   * enhanced: 0.000
#   * enhancing: 0.000
#   * environment: 0.000
#   * environmental: 0.000
#   * essential: 0.000
#   * excels: 0.000
#   * experience: 0.000
#   * experts: 0.000
#   * extracting: 0.000
#   * facilities: 0.000
#   * flexibility: 0.000
#   * footprint: 0.000
#   * for: 0.000
#   * framework: 0.000
#   * future: 0.338
#   * greener: 0.338
#   * have: 0.000
#   * healthy: 0.000
#   * help: 0.000
#   * impact: 0.000
#   * implementing: 0.000
#   * important: 0.000
#   * in: 0.000
#   * individual: 0.338
#   * infrastructure: 0.000
#   * insights: 0.000
#   * inspire: 0.000
#   * integration: 0.000
#   * interface: 0.000
#   * investing: 0.000
#   * is: 0.000
#   * its: 0.000
#   * key: 0.000
#   * landfill: 0.000
#   * learning: 0.000
#   * legislation: 0.000
#   * machine: 0.000
#   * make: 0.338
#   * measures: 0.000
#   * minimize: 0.000
#   * models: 0.000
#   * monitor: 0.000
#   * natural: 0.000
#   * need: 0.000
#   * network: 0.000
#   * new: 0.000
#   * nourish: 0.000
#   * nutrientrich: 0.000
#   * of: 0.000
#   * offer: 0.000
#   * on: 0.000
#   * operate: 0.000
#   * operations: 0.000
#   * options: 0.000
#   * organization: 0.000
#   * organizations: 0.000
#   * our: 0.000
#   * out: 0.000
#   * part: 0.000
#   * partnering: 0.000
#   * performance: 0.000
#   * planet: 0.000
#   * policy: 0.000
#   * pollution: 0.000
#   * potential: 0.000
#   * power: 0.000
#   * practices: 0.000
#   * prediction: 0.000
#   * prioritize: 0.000
#   * priority: 0.000
#   * processing: 0.000
#   * program: 0.000
#   * programs: 0.000
#   * promoting: 0.000
#   * protect: 0.000
#   * protecting: 0.000
#   * protects: 0.000
#   * providing: 0.000
#   * query: 0.000
#   * recycling: 0.000
#   * reduce: 0.000
#   * reducing: 0.000
#   * release: 0.000
#   * remarkably: 0.000
#   * renewable: 0.000
#   * research: 0.000
#   * resources: 0.000
#   * revolutionizing: 0.000
#   * rolled: 0.000
#   * safeguard: 0.000
#   * scalability: 0.000
#   * scientists: 0.000
#   * seamless: 0.000
#   * secure: 0.000
#   * sensitive: 0.000
#   * services: 0.000
#   * sets: 0.000
#   * significantly: 0.000
#   * smoothly: 0.000
#   * software: 0.000
#   * soil: 0.000
#   * solutions: 0.000
#   * sources: 0.000
#   * staying: 0.000
#   * storage: 0.000
#   * streamline: 0.000
#   * strive: 0.000
#   * support: 0.000
#   * sustainability: 0.000
#   * sustainable: 0.000
#   * system: 0.000
#   * tasks: 0.000
#   * team: 0.000
#   * techniques: 0.000
#   * technologies: 0.000
#   * technology: 0.000
#   * that: 0.275
#   * the: 0.000
#   * through: 0.000
#   * to: 0.184
#   * top: 0.000
#   * transportation: 0.000
#   * trends: 0.000
#   * update: 0.000
#   * upgrading: 0.000
#   * us: 0.000
#   * user: 0.000
#   * utilize: 0.000
#   * vital: 0.000
#   * vulnerabilities: 0.000
#   * waste: 0.000
#   * water: 0.000
#   * way: 0.000
#   * we: 0.000
#   * webbased: 0.000
#   * with: 0.000
#   * you: 0.000
#   * zero: 0.000
