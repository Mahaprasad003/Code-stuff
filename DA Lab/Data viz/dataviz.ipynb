# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# define data values

a = [1, 2, 3, 4]
b = [2, 4, 6, 8]

# %%
x = np.array([1, 2, 3, 4])

plt.plot(x, x + 1, linestyle = 'solid')
plt.plot(x, x + 1.5, linestyle = 'dashed')
plt.plot(x, x + 2, linestyle = 'dashdot')
plt.xlabel('Value of X')
plt.ylabel('Value of Y')
plt.title('Line plot')

plt.show()

# %%
df = pd.read_csv('D:\Code-stuff\DA Lab\Assignment-2\water_potability.csv')

# %%
x_values = []
for i in range(len(df['ph'])):
    x_values.append(i)

y_values = df['ph']

# %%
plt.plot(x_values, y_values)

# %%
language = ['C', 'C++', 'Python', 'R']
enrolled = [25, 5, 45, 10]

plt.bar(language, enrolled)
# Out:
# <BarContainer object of 4 artists>

# %%
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
list_pot = df['Potability'].tolist()

x = ['Drinkable', 'Undrinkable'] # Drinkable = 1, Undrinkable = 0
y = [0, 0]

for i in range(len(df['Potability'])):
    if(list_pot[i] == 1):
        y[0] += 1
    else:
        y[1] += 1

# %%
y
# Out:
# [1278, 1998]

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # IRIS dataset

# %%
df = pd.read_csv("Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_setosa_df = df.iloc[:50]

# %%
idOfFlower = iris_setosa_df['Id']
SepalLengthList = iris_setosa_df['SepalLengthCm']

# %%
plt.xlabel("ID")
plt.ylabel("Sepal Length(cm)")
plt.title("Iris setosa")

plt.plot(idOfFlower, SepalLengthList, color = 'green',
        linestyle = 'solid', marker = '*',
        markerfacecolor = 'blue', markersize = 12)
